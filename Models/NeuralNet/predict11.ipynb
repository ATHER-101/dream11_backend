# %%
import json
import csv
import os
from collections import defaultdict
from fantasy_calculator import fantasy_calculator  # Import the fantasy_calculator function

def process_match_data(json_file, output_folder):
    # Extract match ID from the filename
    match_id = os.path.splitext(os.path.basename(json_file))[0]
    
    # Load JSON data
    with open(json_file, 'r') as f:
        data = json.load(f)

    # Extract match info
    match_date = data["info"]["dates"][0]
    venue = data["info"]["venue"]
    event = data["info"].get("event", {}).get("name", "Unknown Event")
    match_type = data["info"]["match_type"]
    total_overs = data["info"]["overs"]
    toss_winner = data["info"]["toss"]["winner"]
    toss_decision = data["info"]["toss"]["decision"]
    teams = data["info"]["teams"]
    innings_data = data["innings"]

    # Map player names to player IDs using the 'registry' section
    player_id_map = {name: str(player_id) for name, player_id in data["info"]["registry"]["people"].items()}
    
    # Map players to their respective teams
    player_team_map = {}
    for team in teams:
        for player in data["info"]["players"][team]:
            player_team_map[player] = team

    # Prepare player stats dictionary
    player_stats = defaultdict(lambda: {
        "date": match_date,
        "venue": venue,
        "event": event,
        "match_type": match_type,
        "total_overs": total_overs,
        "team": None,
        "runs_scored": 0,
        "balls_faced": 0,
        "boundaries": 0,
        "sixes": 0,
        "balls_bowled": 0,
        "wickets": 0,
        "runs_given": 0,
        "bowled_lbw": 0,
        "maidens": 0,
        "catches": 0,
        "stumpings": 0,
        "run_outs": 0
    })

    # Initialize player stats with team information from the rosters
    for player, team in player_team_map.items():
        player_stats[player]["team"] = team

    # Process innings
    for inning in innings_data:
        team = inning["team"]
        overs = inning.get("overs", [])
        for over in overs:
            maidens_flag = True  # To track maiden overs
            for delivery in over["deliveries"]:
                # Batting stats
                batter = delivery["batter"]
                bowler = delivery["bowler"]
                runs = delivery["runs"]["batter"]
                player_stats[batter]["runs_scored"] += runs
                player_stats[batter]["balls_faced"] += 1
                if runs == 4:
                    player_stats[batter]["boundaries"] += 1
                if runs == 6:
                    player_stats[batter]["sixes"] += 1

                # Wicket stats
                if "wickets" in delivery:
                    for wicket in delivery["wickets"]:
                        kind = wicket["kind"]
                        player_out = wicket["player_out"]

                        # Increment the bowler's wickets
                        player_stats[bowler]["wickets"] += 1

                        if kind in {"bowled", "lbw"}:
                            player_stats[bowler]["bowled_lbw"] += 1
                        if kind == "caught":
                            for fielder in wicket.get("fielders", []):
                                player_stats[fielder["name"]]["catches"] += 1
                        if kind == "stumped":
                            player_stats[bowler]["stumpings"] += 1
                        if kind == "run out":
                            for fielder in wicket.get("fielders", []):
                                player_stats[fielder["name"]]["run_outs"] += 1

                # Bowling stats
                if "extras" not in delivery or "wides" not in delivery["extras"] and "no_balls" not in delivery["extras"]:
                    player_stats[bowler]["balls_bowled"] += 1  # Count only legitimate balls

                player_stats[bowler]["runs_given"] += delivery["runs"]["total"]
                if delivery["runs"]["total"] > 0 or "extras" in delivery:
                    maidens_flag = False

            # Update maidens if all deliveries in the over were zero runs
            if maidens_flag:
                player_stats[bowler]["maidens"] += 1

    # Create 'player_data' folder if it does not exist
    os.makedirs(output_folder, exist_ok=True)

    # Write to individual player CSV files
    # for player, stats in player_stats.items():
    #     # Get player ID from the map
    #     player_id = str(player_id_map.get(player, f"Unknown_{player}"))  # Fallback to player name if ID is not found
    #     player_file = os.path.join(output_folder, f"{player_id}.csv")
        
    #     # Own team players
    #     fellow = stats["team"]
    #     fellow_players = [
    #         str(player_id_map.get(p, "Unknown_Player")) 
    #         for p in data["info"]["players"].get(fellow, []) 
    #         if p != player
    #     ]
        
    #     # Opponent team players
    #     opponent_team = teams[1] if teams[0] == fellow else teams[0]
    #     opponent_players = [
    #         str(player_id_map.get(p, "Unknown_Player")) 
    #         for p in data["info"]["players"].get(opponent_team, [])
    #     ]
    # for team in teams:
    #     for player in data["info"]["players"][team]:
    #         player_id = str(player_id_map[player])
    #         player_file = os.path.join(output_folder, f"{player_id}.csv")

    #         opponent_team = teams[1] if teams[0] == team else teams[0]
    #         opp_player_ids = [player_id_map[p] for p in data["info"]["players"][opponent_team][:11]]
    #         fellow_player_ids = [player_id_map[p] for p in data["info"]["players"][team] if p != player][:10]

    #         player_data = {
    #             "match_id": match_id,
    #             "player_id": player_id,
    #             "fellow_player1": fellow_player_ids[0],
    #             "fellow_player2": fellow_player_ids[1],
    #             "fellow_player3": fellow_player_ids[2],
    #             "fellow_player4": fellow_player_ids[3],
    #             "fellow_player5": fellow_player_ids[4],
    #             "fellow_player6": fellow_player_ids[5],
    #             "fellow_player7": fellow_player_ids[6],
    #             "fellow_player8": fellow_player_ids[7],
    #             "fellow_player9": fellow_player_ids[8],
    #             "fellow_player10": fellow_player_ids[9],
    #             # ... (up to fellow_player10)
    #             "opp_player1": opp_player_ids[0],
    #             "opp_player2": opp_player_ids[1],
    #             "opp_player3": opp_player_ids[2],
    #             "opp_player4": opp_player_ids[3],
    #             "opp_player5": opp_player_ids[4],
    #             "opp_player6": opp_player_ids[5],
    #             "opp_player7": opp_player_ids[6],
    #             "opp_player8": opp_player_ids[7],
    #             "opp_player9": opp_player_ids[8],
    #             "opp_player10": opp_player_ids[9],
    #             "opp_player11": opp_player_ids[10]
    #             # ... (up to opponent_player11)
    #         }
    
        # Check if file exists, if not create it with header
        file_exists = os.path.isfile(player_file)
        
        header = [
            "match_id", "date", "venue", "event", "match_type", "total_overs", "player_id", "team",
            "runs_scored", "balls_faced", "boundaries", 
            "sixes", "balls_bowled", "wickets", "runs_given", "bowled_lbw", 
            "maidens", "catches", "stumpings", "run_outs", 
            "batting_points", "bowling_points", "fielding_points", "total_fantasy_points",
            "opp_player1", "opp_player2", "opp_player3", "opp_player4", "opp_player5", 
            "opp_player6", "opp_player7", "opp_player8", "opp_player9", "opp_player10", "opp_player11",
            "fellow_player1", "fellow_player2", "fellow_player3", "fellow_player4",
            "fellow_player5", "fellow_player6", "fellow_player7", "fellow_player8",
            "fellow_player9", "fellow_player10"
        ]
        
        # Open the player CSV file
        with open(player_file, 'a', newline='') as f:
            writer = csv.writer(f)
            # Write the header if the file does not exist
            if not file_exists:
                writer.writerow(header)
            
            # Calculate fantasy points
            batting_points, bowling_points, fielding_points, total_fantasy_points = fantasy_calculator(stats)
            
            # Prepare data for this row
            row = [
                match_id, stats["date"], stats["venue"], stats["event"], stats["match_type"],
                stats["total_overs"], player_id, stats["team"], stats["runs_scored"], stats["balls_faced"],
                stats["boundaries"], stats["sixes"], stats["balls_bowled"], stats["wickets"],
                stats["runs_given"], stats["bowled_lbw"], stats["maidens"], stats["catches"],
                stats["stumpings"], stats["run_outs"], batting_points, bowling_points,
                fielding_points, total_fantasy_points
            ]
            row.extend(opponent_players[:11])  # Add opponent columns
            row.extend(fellow_players[:10])  # Add own team player IDs
            writer.writerow(row)


# Usage example
folder_path = "ipl_json"

# Iterate through all files in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    # Check if it is a file (not a folder)
    if os.path.isfile(file_path) & filename.endswith(".json"):
        process_match_data(file_path, "player_data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 205
#     203 # Check if it is a file (not a folder)
#     204 if os.path.isfile(file_path) & filename.endswith(".json"):
# --> 205     process_match_data(file_path, "player_data")
#
# Cell In[27], line 181, in process_match_data(json_file, output_folder)
#     178     writer.writerow(header)
#     180 # Calculate fantasy points
# --> 181 batting_points, bowling_points, fielding_points, total_fantasy_points = fantasy_calculator(stats)
#     183 # Prepare data for this row
#     184 row = [
#     185     match_id, stats["date"], stats["venue"], stats["event"], stats["match_type"],
#     186     stats["total_overs"], player_id, stats["team"], stats["runs_scored"], stats["balls_faced"],
#    (...)
#     190     fielding_points, total_fantasy_points
#     191 ]
#
# NameError: name 'stats' is not defined

# %%
import json
import csv
import os
from collections import defaultdict
from fantasy_calculator import fantasy_calculator  # Import the fantasy_calculator function

def process_match_data(json_file, output_folder):
    # Load JSON data
    with open(json_file, 'r') as f:
        data = json.load(f)

    # Extract match info
    match_date = data["info"]["dates"][0]
    venue = data["info"]["venue"]
    event = data["info"].get("event", {}).get("name", "Unknown Event")
    match_type = data["info"]["match_type"]
    total_overs = data["info"]["overs"]
    toss_winner = data["info"]["toss"]["winner"]
    toss_decision = data["info"]["toss"]["decision"]
    teams = data["info"]["teams"]
    innings_data = data["innings"]

    # Map player names to player IDs using the 'registry' section
    player_id_map = {name: str(player_id) for name, player_id in data["info"]["registry"]["people"].items()}
    
    # Map players to their respective teams
    player_team_map = {}
    for team in teams:
        for player in data["info"]["players"][team]:
            player_team_map[player] = team

    # Prepare player stats dictionary
    player_stats = defaultdict(lambda: {
        "date": match_date,
        "venue": venue,
        "event": event,
        "match_type": match_type,
        "total_overs": total_overs,
        "team": None,
        "runs_scored": 0,
        "balls_faced": 0,
        "boundaries": 0,
        "sixes": 0,
        "balls_bowled": 0,
        "wickets": 0,
        "runs_given": 0,
        "bowled_lbw": 0,
        "maidens": 0,
        "catches": 0,
        "stumpings": 0,
        "run_outs": 0
    })

    # Initialize player stats with team information from the rosters
    for player, team in player_team_map.items():
        player_stats[player]["team"] = team

    # Process innings
    for inning in innings_data:
        team = inning["team"]
        overs = inning.get("overs", [])
        for over in overs:
            maidens_flag = True  # To track maiden overs
            for delivery in over["deliveries"]:
                # Batting stats
                batter = delivery["batter"]
                bowler = delivery["bowler"]
                runs = delivery["runs"]["batter"]
                player_stats[batter]["runs_scored"] += runs
                player_stats[batter]["balls_faced"] += 1
                if runs == 4:
                    player_stats[batter]["boundaries"] += 1
                if runs == 6:
                    player_stats[batter]["sixes"] += 1

                # Wicket stats
                if "wickets" in delivery:
                    for wicket in delivery["wickets"]:
                        kind = wicket["kind"]
                        player_out = wicket["player_out"]

                        # Increment the bowler's wickets
                        player_stats[bowler]["wickets"] += 1

                        if kind in {"bowled", "lbw"}:
                            player_stats[bowler]["bowled_lbw"] += 1
                        if kind == "caught":
                            for fielder in wicket.get("fielders", []):
                                player_stats[fielder["name"]]["catches"] += 1
                        if kind == "stumped":
                            player_stats[bowler]["stumpings"] += 1
                        if kind == "run out":
                            for fielder in wicket.get("fielders", []):
                                player_stats[fielder["name"]]["run_outs"] += 1

                # Bowling stats
                if "extras" not in delivery or "wides" not in delivery["extras"] and "no_balls" not in delivery["extras"]:
                    player_stats[bowler]["balls_bowled"] += 1  # Count only legitimate balls

                player_stats[bowler]["runs_given"] += delivery["runs"]["total"]
                if delivery["runs"]["total"] > 0 or "extras" in delivery:
                    maidens_flag = False

            # Update maidens if all deliveries in the over were zero runs
            if maidens_flag:
                player_stats[bowler]["maidens"] += 1

    # Add opponent playing XI
    for player in player_stats:
        team = player_stats[player]["team"]
        opponent_team = teams[1] if teams[0] == team else teams[0]
        opponent_playing_xi = data["info"]["players"].get(opponent_team, [])
        
        for i, opponent_player in enumerate(opponent_playing_xi[:11]):
            # Validate opponent player and assign default if missing
            player_stats[player][f"player{i+1}"] = opponent_player

        # Validate opponent player columns before writing
        for i in range(11):
            col_name = f"player{i+1}"
            if not isinstance(player_stats[player][col_name], str):
                player_stats[player][col_name] = "Unknown_Player"

    # Create 'player_data' folder if it does not exist
    os.makedirs(output_folder, exist_ok=True)

    # Write to individual player CSV files
    for player, stats in player_stats.items():
        # Use player name as the filename
        player_name = player
        player_file = os.path.join(output_folder, f"{player_name}.csv")
        
        print(f"Processing player: {player}, Player Name: {player_name}, File: {player_file}")  # Debugging statement
        
        # Check if file exists, if not create it with header
        file_exists = os.path.isfile(player_file)
        
        header = [
            "date", "venue", "event", "match_type", "total_overs", "player_name", "team",
            "runs_scored", "balls_faced", "boundaries", 
            "sixes", "balls_bowled", "wickets", "runs_given", "bowled_lbw", 
            "maidens", "catches", "stumpings", "run_outs", 
            "batting_points", "bowling_points", "fielding_points", "total_fantasy_points",
            "player1", "player2", "player3", "player4", "player5", "player6", 
            "player7", "player8", "player9", "player10", "player11"
        ]
        
        # Open the player CSV file
        with open(player_file, 'a', newline='') as f:
            writer = csv.writer(f)
            # Write the header if the file does not exist
            if not file_exists:
                writer.writerow(header)
            
            # Calculate fantasy points
            batting_points, bowling_points, fielding_points, total_fantasy_points = fantasy_calculator(stats)
            
            # Prepare data for this row
            # Prepare data for this row (all stats except the fantasy points and opponent players)
# Prepare the main stats row (excluding fantasy points and opponent players)
            row = [str(stats[col]) if col in stats else "0" for col in header[:19]]  # All columns except fantasy points and opponent players

            # Replace player_name instead of player_id for 'player_name' column
            row[5] = player_name  # Player name column (instead of player_id)

            # Append the calculated fantasy points (batting, bowling, fielding, and total)
            row.append(batting_points)  # Batting points
            row.append(bowling_points)  # Bowling points
            row.append(fielding_points)  # Fielding points
            row.append(total_fantasy_points)  # Total fantasy points

            # Add opponent player names to the row (after the fantasy points)
            row.extend([str(stats.get(f"player{i+1}", "Unknown_Player")) for i in range(11)])

            # Write the row to the CSV file
            writer.writerow(row)

# %%
folder_path = "ipl_json"

# Iterate through all files in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    # Check if it is a file (not a folder)
    if os.path.isfile(file_path) & filename.endswith(".json"):
        process_match_data(file_path, "player_csv")
# Out:
# Processing player: DA Warner, Player Name: DA Warner, File: player_csv\DA Warner.csv
# Processing player: S Dhawan, Player Name: S Dhawan, File: player_csv\S Dhawan.csv
# Processing player: MC Henriques, Player Name: MC Henriques, File: player_csv\MC Henriques.csv
# Processing player: Yuvraj Singh, Player Name: Yuvraj Singh, File: player_csv\Yuvraj Singh.csv
# Processing player: DJ Hooda, Player Name: DJ Hooda, File: player_csv\DJ Hooda.csv
# Processing player: BCJ Cutting, Player Name: BCJ Cutting, File: player_csv\BCJ Cutting.csv
# Processing player: NV Ojha, Player Name: NV Ojha, File: player_csv\NV Ojha.csv
# Processing player: Bipul Sharma, Player Name: Bipul Sharma, File: player_csv\Bipul Sharma.csv
# Processing player: B Kumar, Player Name: B Kumar, File: player_csv\B Kumar.csv
# Processing player: A Nehra, Player Name: A Nehra, File: player_csv\A Nehra.csv
# Processing player: Rashid Khan, Player Name: Rashid Khan, File: player_csv\Rashid Khan.csv
# Processing player: CH Gayle, Player Name: CH Gayle, File: player_csv\CH Gayle.csv
# Processing player: Mandeep Singh, Player Name: Mandeep Singh, File: player_csv\Mandeep Singh.csv
# Processing player: TM Head, Player Name: TM Head, File: player_csv\TM Head.csv
# Processing player: KM Jadhav, Player Name: KM Jadhav, File: player_csv\KM Jadhav.csv
# Processing player: SR Watson, Player Name: SR Watson, File: player_csv\SR Watson.csv
# Processing player: Sachin Baby, Player Name: Sachin Baby, File: player_csv\Sachin Baby.csv
# Processing player: STR Binny, Player Name: STR Binny, File: player_csv\STR Binny.csv
# Processing player: S Aravind, Player Name: S Aravind, File: player_csv\S Aravind.csv
# Processing player: TS Mills, Player Name: TS Mills, File: player_csv\TS Mills.csv
# Processing player: YS Chahal, Player Name: YS Chahal, File: player_csv\YS Chahal.csv
# Processing player: A Choudhary, Player Name: A Choudhary, File: player_csv\A Choudhary.csv
# Processing player: CJ Jordan, Player Name: CJ Jordan, File: player_csv\CJ Jordan.csv
# Processing player: AM Rahane, Player Name: AM Rahane, File: player_csv\AM Rahane.csv
# Processing player: MA Agarwal, Player Name: MA Agarwal, File: player_csv\MA Agarwal.csv
# Processing player: SPD Smith, Player Name: SPD Smith, File: player_csv\SPD Smith.csv
# Processing player: BA Stokes, Player Name: BA Stokes, File: player_csv\BA Stokes.csv
# Processing player: MS Dhoni, Player Name: MS Dhoni, File: player_csv\MS Dhoni.csv
# Processing player: MK Tiwary, Player Name: MK Tiwary, File: player_csv\MK Tiwary.csv
# Processing player: R Bhatia, Player Name: R Bhatia, File: player_csv\R Bhatia.csv
# Processing player: DL Chahar, Player Name: DL Chahar, File: player_csv\DL Chahar.csv
# Processing player: A Zampa, Player Name: A Zampa, File: player_csv\A Zampa.csv
# Processing player: AB Dinda, Player Name: AB Dinda, File: player_csv\AB Dinda.csv
# Processing player: Imran Tahir, Player Name: Imran Tahir, File: player_csv\Imran Tahir.csv
# Processing player: PA Patel, Player Name: PA Patel, File: player_csv\PA Patel.csv
# Processing player: JC Buttler, Player Name: JC Buttler, File: player_csv\JC Buttler.csv
# Processing player: MP Stoinis, Player Name: MP Stoinis, File: player_csv\MP Stoinis.csv
# Processing player: Swapnil Singh, Player Name: Swapnil Singh, File: player_csv\Swapnil Singh.csv
# Processing player: MM Sharma, Player Name: MM Sharma, File: player_csv\MM Sharma.csv
# Processing player: Sandeep Sharma, Player Name: Sandeep Sharma, File: player_csv\Sandeep Sharma.csv
# Processing player: T Natarajan, Player Name: T Natarajan, File: player_csv\T Natarajan.csv
# Processing player: AM Rahane, Player Name: AM Rahane, File: player_csv\AM Rahane.csv
# Processing player: MA Agarwal, Player Name: MA Agarwal, File: player_csv\MA Agarwal.csv
# Processing player: SPD Smith, Player Name: SPD Smith, File: player_csv\SPD Smith.csv
# Processing player: BA Stokes, Player Name: BA Stokes, File: player_csv\BA Stokes.csv
# Processing player: MS Dhoni, Player Name: MS Dhoni, File: player_csv\MS Dhoni.csv
# Processing player: MK Tiwary, Player Name: MK Tiwary, File: player_csv\MK Tiwary.csv
# Processing player: DT Christian, Player Name: DT Christian, File: player_csv\DT Christian.csv
# Processing player: R Bhatia, Player Name: R Bhatia, File: player_csv\R Bhatia.csv
# Processing player: RD Chahar, Player Name: RD Chahar, File: player_csv\RD Chahar.csv
# Processing player: Imran Tahir, Player Name: Imran Tahir, File: player_csv\Imran Tahir.csv
# Processing player: AB Dinda, Player Name: AB Dinda, File: player_csv\AB Dinda.csv
# Processing player: CH Gayle, Player Name: CH Gayle, File: player_csv\CH Gayle.csv
# Processing player: SR Watson, Player Name: SR Watson, File: player_csv\SR Watson.csv
# Processing player: Mandeep Singh, Player Name: Mandeep Singh, File: player_csv\Mandeep Singh.csv
# Processing player: KM Jadhav, Player Name: KM Jadhav, File: player_csv\KM Jadhav.csv
# Processing player: STR Binny, Player Name: STR Binny, File: player_csv\STR Binny.csv
# Processing player: Vishnu Vinod, Player Name: Vishnu Vinod, File: player_csv\Vishnu Vinod.csv
# Processing player: P Negi, Player Name: P Negi, File: player_csv\P Negi.csv
# Processing player: Iqbal Abdulla, Player Name: Iqbal Abdulla, File: player_csv\Iqbal Abdulla.csv
# Processing player: TS Mills, Player Name: TS Mills, File: player_csv\TS Mills.csv
# Processing player: YS Chahal, Player Name: YS Chahal, File: player_csv\YS Chahal.csv
# Processing player: B Stanlake, Player Name: B Stanlake, File: player_csv\B Stanlake.csv
# Processing player: AP Tare, Player Name: AP Tare, File: player_csv\AP Tare.csv
# Processing player: SW Billings, Player Name: SW Billings, File: player_csv\SW Billings.csv
# Processing player: KK Nair, Player Name: KK Nair, File: player_csv\KK Nair.csv
# Processing player: SV Samson, Player Name: SV Samson, File: player_csv\SV Samson.csv
# Processing player: RR Pant, Player Name: RR Pant, File: player_csv\RR Pant.csv
# Processing player: CH Morris, Player Name: CH Morris, File: player_csv\CH Morris.csv
# Processing player: CR Brathwaite, Player Name: CR Brathwaite, File: player_csv\CR Brathwaite.csv
# Processing player: PJ Cummins, Player Name: PJ Cummins, File: player_csv\PJ Cummins.csv
# Processing player: A Mishra, Player Name: A Mishra, File: player_csv\A Mishra.csv
# Processing player: S Nadeem, Player Name: S Nadeem, File: player_csv\S Nadeem.csv
# Processing player: Z Khan, Player Name: Z Khan, File: player_csv\Z Khan.csv
# Processing player: DA Warner, Player Name: DA Warner, File: player_csv\DA Warner.csv
# Processing player: S Dhawan, Player Name: S Dhawan, File: player_csv\S Dhawan.csv
# Processing player: MC Henriques, Player Name: MC Henriques, File: player_csv\MC Henriques.csv
# Processing player
# Processing player: CR Woakes, Player Name: CR Woakes, File: player_csv\CR Woakes.csv
# Processing player: SP Narine, Player Name: SP Narine, File: player_csv\SP Narine.csv
# Processing player: Kuldeep Yadav, Player Name: Kuldeep Yadav, File: player_csv\Kuldeep Yadav.csv
# Processing player: AS Rajpoot, Player Name: AS Rajpoot, File: player_csv\AS Rajpoot.csv
# Processing player: TA Boult, Player Name: TA Boult, File: player_csv\TA Boult.csv
# Processing player: R Dhawan, Player Name: R Dhawan, File: player_csv\R Dhawan.csv
# Processing player: M Vohra, Player Name: M Vohra, File: player_csv\M Vohra.csv
# Processing player: HM Amla, Player Name: HM Amla, File: player_csv\HM Amla.csv
# Processing player: AR Patel, Player Name: AR Patel, File: player_csv\AR Patel.csv
# Processing player: GJ Maxwell, Player Name: GJ Maxwell, File: player_csv\GJ Maxwell.csv
# Processing player: WP Saha, Player Name: WP Saha, File: player_csv\WP Saha.csv
# Processing player: DA Miller, Player Name: DA Miller, File: player_csv\DA Miller.csv
# Processing player: MP Stoinis, Player Name: MP Stoinis, File: player_csv\MP Stoinis.csv
# Processing player: MM Sharma, Player Name: MM Sharma, File: player_csv\MM Sharma.csv
# Processing player: Sandeep Sharma, Player Name: Sandeep Sharma, File: player_csv\Sandeep Sharma.csv
# Processing player: VR Aaron, Player Name: VR Aaron, File: player_csv\VR Aaron.csv
# Processing player: T Natarajan, Player Name: T Natarajan, File: player_csv\T Natarajan.csv
# Processing player: SR Watson, Player Name: SR Watson, File: player_csv\SR Watson.csv
# Processing player: Vishnu Vinod, Player Name: Vishnu Vinod, File: player_csv\Vishnu Vinod.csv
# Processing player: AB de Villiers, Player Name: AB de Villiers, File: player_csv\AB de Villiers.csv
# Processing player: KM Jadhav, Player Name: KM Jadhav, File: player_csv\KM Jadhav.csv
# Processing player: Mandeep Singh, Player Name: Mandeep Singh, File: player_csv\Mandeep Singh.csv
# Processing player: STR Binny, Player Name: STR Binny, File: player_csv\STR Binny.csv
# Processing player: P Negi, Player Name: P Negi, File: player_csv\P Negi.csv
# Processing player: Iqbal Abdulla, Player Name: Iqbal Abdulla, File: player_csv\Iqbal Abdulla.csv
# Processing player: TS Mills, Player Name: TS Mills, File: player_csv\TS Mills.csv
# Processing player: B Stanlake, Player Name: B Stanlake, File: player_csv\B Stanlake.csv
# Processing player: YS Chahal, Player Name: YS Chahal, File: player_csv\YS Chahal.csv
# Processing player: AM Rahane, Player Name: AM Rahane, File: player_csv\AM Rahane.csv
# Processing player: MA Agarwal, Player Name: MA Agarwal, File: player_csv\MA Agarwal.csv
# Processing player: F du Plessis, Player Name: F du Plessis, File: player_csv\F du Plessis.csv
# Processing player: RA Tripathi, Player Name: RA Tripathi, File: player_csv\RA Tripathi.csv
# Processing player: BA Stokes, Player Name: BA Stokes, File: player_csv\BA Stokes.csv
# Processing player: MS Dhoni, Player Name: MS Dhoni, File: player_csv\MS Dhoni.csv
# Processing player: R Bhatia, Player Name: R Bhatia, File: player_csv\R Bhatia.csv
# Processing player: DL Chahar, Player Name: DL Chahar, File: player_csv\DL Chahar.csv
# Processing player: CR Woakes, Player Name: CR Woakes, File: player_csv\CR Woakes.csv
# Processing player: C de Grandhomme, Player Name: C de Grandhomme, File: player_csv\C de Grandhomme.csv
# Processing player: PP Chawla, Player Name: PP Chawla, File: player_csv\PP Chawla.csv
# Processing player: UT Yadav, Player Name: UT Yadav, File: player_csv\UT Yadav.csv
# Processing player: TA Boult, Player Name: TA Boult, File: player_csv\TA Boult.csv
# Processing player: HM Amla, Player Name: HM Amla, File: player_csv\HM Amla.csv
# Processing player: M Vohra, Player Name: M Vohra, File: player_csv\M Vohra.csv
# Processing player: MP Stoinis, Player Name: MP Stoinis, File: player_csv\MP Stoinis.csv
# Processing player: GJ Maxwell, Player Name: GJ Maxwell, File: player_csv\GJ Maxwell.csv
# Processing player: DA Miller, Player Name: DA Miller, File: player_csv\DA Miller.csv
# Processing player: WP Saha, Player Name: WP Saha, File: player_csv\WP Saha.csv
# Processing player: AR Patel, Player Name: AR Patel, File: player_csv\AR Patel.csv
# Processing player: MM Sharma, Player Name: MM Sharma, File: player_csv\MM Sharma.csv
# Processing player: VR Aaron, Player Name: VR Aaron, File: player_csv\VR Aaron.csv
# Processing player: Sandeep Sharma, Player Name: Sandeep Sharma, File: player_csv\Sandeep Sharma.csv
# Processing player: I Sharma, Player Name: I Sharma, File: player_csv\I Sharma.csv
# Processing player: CH Gayle, Player Name: CH Gayle, File: player_csv\CH Gayle.csv
# Processing player: V Kohli, Player Name: V Kohli, File: player_csv\V Kohli.csv
# Processing player: AB de Villiers, Player Name: AB de Villiers, File: player_csv\AB de Villiers.csv
# Processing player: KM Jadhav, Player Name: KM Jadhav, File: player_csv\KM Jadhav.csv
# Processing player: P Negi, Player Name: P Negi, File: player_csv\P Negi.csv
# Processing player: Mandeep Singh, Player Name: Mandeep Singh, File: player_csv\Mandeep Singh.csv
# Processing player: STR Binny, Player Name: STR Binny, File: player_csv\STR Binny.csv
# Processing player: TS Mills, Player Name: TS Mills, File: player_csv\TS Mills.csv
# Processing player: S Aravind, Player Name: S Aravind, File: player_csv\S Aravind.csv
# Processing player: YS Chahal, Player Name: YS Chahal, File: player_csv\YS Chahal.csv
# Processing player: S Badree, Player Name: S Badree, File: player_csv\S Badree.csv
# Processing player: PA Patel, Player Name: PA Patel, File: player_csv\PA Patel.csv
# Processing player: JC Buttler, Player Name: JC Buttler, File: player_csv\JC Buttler.csv
# Processing player: RG Sharma, Player Name: RG Sharma, File: player_csv\RG Sharma.csv
# Processing player: MJ McClenaghan, Player Name: MJ McClenaghan, File: player_csv\MJ McClenaghan.csv
# Processing player: N Rana, Player Name: N Rana, File: player_csv\N Rana.csv
# Processing player: KA Pollard, Player Name: KA Pollard, File: player_csv\KA Pollard.csv
# Processing player: KH Pandya, Player Name: KH Pandya, File: player_csv\KH Pandya.csv
# Processing player: HH Pandya, Player Name: HH Pandya, File: player_csv\HH Pandya.csv
# Processing player: Harbhajan Singh, Player Name: Harbhajan Singh, File: player_csv\Harbhajan Singh.csv
# Processing player: JJ Bumrah, Player Name: JJ Bumrah, File: player_csv\JJ Bumrah.csv
# Processing player: TG Southee, Player Name: TG Southee, File: player_csv\TG Southee.csv
# Processing player: DR Smith, Player Name: DR Smith, File: player_csv\DR Smith.csv
# Processing player: BB McCullum, Player Name: BB McCullum, File: player_csv\BB McCullum.csv
# Processing player: SK Raina, Player Name: SK Raina, File: player_csv\SK Raina.csv
# Processing player: KD Karthik, Player Name: KD Karthik, File: player_csv\KD Karthik.csv
# Processing player: AJ Finch, Player Name: AJ Finch, File: player_csv\AJ Finch.csv
# Processing player: Ishan Kishan, Player Name: Ishan Kishan, File: player_csv\Ishan Kishan.csv
# Processing player: RA Jadeja, Player Name: RA Jadeja, File: player_csv\RA Jadeja.csv
# Processing player: P Kumar, Player Name: P Kumar, File: player_csv\P Kumar.csv
# Processing player: Basil Thampi, Player Name: Basil Thampi, File: player_csv\Basil Thampi.csv
# Processing player: AJ Tye, Player Name: AJ Tye, File: player_csv\AJ Tye.csv
# Processing player: SB Jakati, Player Name: SB Jakati, File: player_csv\SB Jakati.csv
# Processing player: AM Rahane, Player Name: AM Rahane, File: player_csv\AM Rahane.csv
# Processing player: RA Tripathi, Player Name: RA Tripathi, File: player_csv\RA Tripathi.csv
# Processing player: SPD Smith, Player Name: SPD Smith, File: player_csv\SPD Smith.csv
# Processing player: BA Stokes, Player Name: BA Stokes, File: player_csv\BA Stokes.csv
# Processing player: MK Tiwary, Player Name: MK Tiwary, File: player_csv\MK Tiwary.csv
# Processing player: MS Dhoni, Player Name: MS Dhoni, File: player_csv\MS Dhoni.csv
# Processing player: Ankit Sharma, Player Name: Ankit Sharma, File: player_csv\Ankit Sharma.csv
# Processing player: SN Thakur, Player Name: SN Thakur, File: player_csv\SN Thakur.csv
# Processing player: LH Ferguson, Player Name: LH Ferguson, File: player_csv\LH Ferguson.csv
# Processing player: RD Chahar, Player Name: RD Chahar, File: player_csv\RD Chahar.csv
# Processing player: Imran Tahir, Player Name: Imran Tahir, File: player_csv\Imran Tahir.csv
# Processing player: SP Narine, Player Name: SP Narine, File: player_csv\SP Narine.csv
# Processing player: G Gambhir, Player Name: G Gambhir, File: player_csv\G Gambhir.csv
# Processing player: RV Uthappa, Player Name: RV Uthappa, File: player_csv\RV Uthappa.csv
# Processing player: MK Pandey, Player Name: MK Pandey, File: player_csv\MK Pandey.csv
# Processing player: YK Pathan, Player Name: YK Pathan, File: player_csv\YK Pathan.csv
# Processing player: SA Yadav, Player Name: SA Yadav, File: player_csv\SA Yadav.csv
# Processing player: C de Grandhomme, Player Name: C de Grandhomme, File: player_csv\C de Grandhomme.csv
# Processing player: CR Woakes, Player Name: CR Woakes, File: player_csv\CR Woakes.csv
# Processing player: Kuldeep Yadav, Player Name: Kuldeep Yadav, File: player_csv\Kuldeep Yadav.csv
# Processing player: UT Yadav, Player Name: UT Yadav, File: player_csv\UT Yadav.csv
# Processing player: TA Boult, Player Name: TA Boult, File: player_csv\TA Boult.csv
# Processing player: DA Warner, Player Name: DA Warner, File: player_csv\DA Warner.csv
# Processing player: S Dhawan, Player Name: S Dhawan, File: player_csv\S Dhawan.csv
# Processing player: MC Henriques, Player Name: MC Henriques, File: player_csv\MC Henriques.csv
# Processing player: Yuvraj Singh, Player Name: Yuvraj Singh, File: player_csv\Yuvraj Singh.csv
# Processing player: DJ Hooda, Player Name: DJ Hooda, File: player_csv\DJ Hooda.csv
# Processing player: BCJ Cutting, Player Name: BCJ Cutting, File: player_csv\BCJ Cutting.csv
# Processing player: NV Ojha, Player Name: NV Ojha, File: player_csv\NV Ojha.csv
# Processing player: Bipul Sharma, Player Name: Bipul Sharma, File: player_csv\Bipul Sharma.csv
# Processing player: B Kumar, Player Name: B Kumar, File: player_csv\B Kumar.csv
# Processing player: Rashid Khan, Player Name: Rashid Khan, File: player_csv\Rashid Khan.csv
# Processing player: A Nehra, Player Name: A Nehra, File: player_csv\A Nehra.csv
# Processing player: R Dhawan, Player Name: R Dhawan, File: player_csv\R Dhawan.csv
# Processing player: SV Samson, Player Name: SV Samson, File: player_csv\SV Samson.csv
# Processing player: SW Billings, Player Name: SW Billings, File: player_csv\SW Billings.csv
# Processing player: KK Nair, Player Name: KK Nair, File: player_csv\KK Nair.csv
# Processing player: SS Iyer, Player Name: SS Iyer, File: player_csv\SS Iyer.csv
# Processing player: RR Pant, Player Name: RR Pant, File: player_csv\RR Pant.csv
# Processing player: CJ Anderson, Player Name: CJ Anderson, File: player_csv\CJ Anderson.csv
# Processing player: CH Morris, Player Name: CH Morris, File: player_csv\CH Morris.csv
# Processing player: PJ Cummins, Player Name: PJ Cummins, File: player_csv\PJ Cummins.csv
# Processing player: A Mishra, Player Name: A Mishra, File: player_csv\A Mishra.csv
# Processing player: Z Khan, Player Name: Z Khan, File: player_csv\Z Khan.csv
# Processing player: S Nadeem, Player Name: S Nadeem, File: player_csv\S Nadeem.csv
# Processing player: M Vohra, Player Name: M Vohra, File: player_csv\M Vohra.csv
# Processing player: HM Amla, Player Name: HM Amla, File: player_csv\HM Amla.csv
# Processing player: WP Saha, Player Name: WP Saha, File: player_csv\WP Saha.csv
# Processing player: EJG Morgan, Player Name: EJG Morgan, File: player_csv\EJG Morgan.csv
# Processing player: DA Miller, Player Name: DA Miller, File: player_csv\DA Miller.csv
# Processing player: GJ Maxwell, Player Name: GJ Maxwell, File: player_csv\GJ Maxwell.csv
# Processing player: AR Patel, Player Name: AR Patel, File: player_csv\AR Patel.csv
# Processing player: MM Sharma, Player Name: MM Sharma, File: player_csv\MM Sharma.csv
# Processing player: KC Cariappa, Player Name: KC Cariappa, File: player_csv\KC Cariappa.csv
# Processing player: Sandeep Sharma, Player Name: Sandeep Sharma, File: player_csv\Sandeep Sharma.csv
# Processing player: VR Aaron, Player Name: VR Aaron, File: player_csv\VR Aaron.csv
# Processing player: PA Patel, Player Name: PA Patel, File: player_csv\PA Patel.csv
# Processing player: JC Buttler, Player Name: JC Buttler, File: player_csv\JC Buttler.csv
# Processing player: N Rana, Player Name: N Rana, File: player_csv\N Rana.csv
# Processing player: RG Sharma, Player Name: RG Sharma, File: player_csv\RG Sharma.csv
# Processing player: KA Pollard, Player Name: KA Pollard, File: player_csv\KA Pollard.csv
# Processing player: HH Pandya, Player Name: HH Pandya, File: player_csv\HH Pandya.csv
# Processing player: KH Pandya, Player Name: KH Pandya, File: player_csv\KH Pandya.csv
# Processing player: Harbhajan Singh, Player Name: Harbhajan Singh, File: player_csv\Harbhajan Singh.csv
# Processing player: MJ McClenaghan, Player Name: MJ McClenaghan, File: player_csv\MJ McClenaghan.csv
# Processing player: SL Malinga, Player Name: SL Malinga, File: player_csv\SL Malinga.csv
# Processing player: SS Iyer, Player Name: SS Iyer, File: player_csv\SS Iyer.csv
# Processing player: RR Pant, Player Name: RR Pant, File: player_csv\RR Pant.csv
# Processing player: AD Mathews, Player Name: AD Mathews, File: player_csv\AD Mathews.csv
# Processing player: CH Morris, Player Name: CH Morris, File: player_csv\CH Morris.csv
# Processing player: PJ Cummins, Player Name: PJ Cummins, File: player_csv\PJ Cummins.csv
# Processing player: Mohammed Shami, Player Name: Mohammed Shami, File: player_csv\Mohammed Shami.csv
# Processing player: A Mishra, Player Name: A Mishra, File: player_csv\A Mishra.csv
# Processing player: Z Khan, Player Name: Z Khan, File: player_csv\Z Khan.csv
# Processing player: G Gambhir, Player Name: G Gambhir, File: player_csv\G Gambhir.csv
# Processing player: C de Grandhomme, Player Name: C de Grandhomme, File: player_csv\C de Grandhomme.csv
# Processing player: RV Uthappa, Player Name: RV Uthappa, File: player_csv\RV Uthappa.csv
# Processing player: MK Pandey, Player Name: MK Pandey, File: player_csv\MK Pandey.csv
# Processing player: YK Pathan, Player Name: YK Pathan, File: player_csv\YK Pathan.csv
# Processing player: SA Yadav, Player Name: SA Yadav, File: player_csv\SA Yadav.csv
# Processing player: CR Woakes, Player Name: CR Woakes, File: player_csv\CR Woakes.csv
# Processing player: SP Narine, Player Name: SP Narine, File: player_csv\SP Narine.csv
# Processing player: NM Coulter-Nile, Player Name: NM Coulter-Nile, File: player_csv\NM Coulter-Nile.csv
# Processing player: Kuldeep Yadav, Player Name: Kuldeep Yadav, File: player_csv\Kuldeep Yadav.csv
# Processing player: UT Yadav, Player Name: UT Yadav, File: player_csv\UT Yadav.csv
# Processing player: DA Warner, Player Name: DA Warner, File: player_csv\DA Warner.csv
# Processing player: S Dhawan, Player Name: S Dhawan, File: player_csv\S Dhawan.csv
# Processing player: MC Henriques, Player Name: MC Henriques, File: player_csv\MC Henriques.csv
# Processing player: Yuvraj Singh, Player Name: Yuvraj Singh, File: player_csv\Yuvraj Singh.csv
# Processing player: NV Ojha, Player Name: NV Ojha, File: player_csv\NV Ojha.csv
# Processing player: DJ Hooda, Player Name: DJ Hooda, File: player_csv\DJ Hooda.csv
# Processing player: Mohammad Nabi, Player Name: Mohammad Nabi, File: player_csv\Mohammad Nabi.csv
# Processing player: Rashid Khan, Player Name: Rashid Khan, File: player_csv\Rashid Khan.csv
# Processing player: B Kumar, Player Name: B Kumar, File: player_csv\B Kumar.csv
# Processing player: BB Sran, Player Name: BB Sran, File: player_csv\BB Sran.csv
# Processing player: S Kaul, Player Name: S Kaul, File: player_csv\S Kaul.csv
# Processing player: HM Amla, Player Name: HM Amla, File: player_csv\HM Amla.csv
# Processing player: M Vohra, Player Name: M Vohra, File: player_csv\M Vohra.csv
# Processing player: GJ Maxwell, Player Name: GJ Maxwell, File: player_csv\GJ Maxwell.csv
# Processing player: EJG Morgan, Player Name: EJG Morgan, File: player_csv\EJG Morgan.csv
# Processing player: DA Miller, Player Name: DA Miller, File: player_csv\DA Miller.csv
# Processing player: WP Saha, Player Name: WP Saha, File: player_csv\WP Saha.csv
# Processing player: AR Patel, Player Name: AR Patel, File: player_csv\AR Patel.csv
# Processing player: MM Sharma, Player Name: MM Sharma, File: player_csv\MM Sharma.csv
# Processing player: KC Cariappa, Player Name: KC Cariappa, File: player_csv\KC Cariappa.csv
# Processing player: I Sharma, Player Name: I Sharma, File: player_csv\I Sharma.csv
# Processing player: Sandeep Sharma, Player Name: Sandeep Sharma, File: player_csv\Sandeep Sharma.csv
# Processing player: DR Smith, Player Name: DR Smith, File: player_csv\DR Smith.csv
# Processing player: BB McCullum, Player Name: BB McCullum, File: player_csv\BB McCullum.csv
# Processing player: SK Raina, Player Name: SK Raina, File: player_csv\SK Raina.csv
# Processing player: KD Karthik, Player Name: KD Karthik, File: player_csv\KD Karthik.csv
# Processing player: Ishan Kishan, Player Name: Ishan Kishan, File: player_csv\Ishan Kishan.csv
# Processing player: DR Smith, Player Name: DR Smith, File: player_csv\DR Smith.csv
# Processing player: RA Jadeja, Player Name: RA Jadeja, File: player_csv\RA Jadeja.csv
# Processing player: JP Faulkner, Player Name: JP Faulkner, File: player_csv\JP Faulkner.csv
# Processing player: P Kumar, Player Name: P Kumar, File: player_csv\P Kumar.csv
# Processing player: Basil Thampi, Player Name: Basil Thampi, File: player_csv\Basil Thampi.csv
# Processing player: DS Kulkarni, Player Name: DS Kulkarni, File: player_csv\DS Kulkarni.csv
# Processing player: PA Patel, Player Name: PA Patel, File: player_csv\PA Patel.csv
# Processing player: JC Buttler, Player Name: JC Buttler, File: player_csv\JC Buttler.csv
# Processing player: N Rana, Player Name: N Rana, File: player_csv\N Rana.csv
# Processing player: RG Sharma, Player Name: RG Sharma, File: player_csv\RG Sharma.csv
# Processing player: KA Pollard, Player Name: KA Pollard, File: player_csv\KA Pollard.csv
# Processing player: KH Pandya, Player Name: KH Pandya, File: player_csv\KH Pandya.csv
# Processing player: HH Pandya, Player Name: HH Pandya, File: player_csv\HH Pandya.csv
# Processing player: Harbhajan Singh, Player Name: Harbhajan Singh, File: player_csv\Harbhajan Singh.csv
# Processing player: MJ McClenaghan, Player Name: MJ McClenaghan, File: player_csv\MJ McClenaghan.csv
# Processing player: MG Johnson, Player Name: MG Johnson, File: player_csv\MG Johnson.csv
# Processing player: JJ Bumrah, Player Name: JJ Bumrah, File: player_csv\JJ Bumrah.csv
# Processing player: SV Samson, Player Name: SV Samson, File: player_csv\SV Samson.csv
# Processing player: AP Tare, Player Name: AP Tare, File: player_csv\AP Tare.csv
# Processing player: KK Nair, Player Name: KK Nair, File: player_csv\KK Nair.csv
# Processing player: SS Iyer, Player Name: SS Iyer, File: player_csv\SS Iyer.csv
# Processing player: CJ Anderson, Player Name: CJ Anderson, File: player_csv\CJ Anderson.csv
# Processing player: RR Pant, Player Name: RR Pant, File: player_csv\RR Pant.csv
# Processing player: K Rabada, Player Name: K Rabada, File: player_csv\K Rabada.csv
# Processing player: CH Morris, Player Name: CH Morris, File: player_csv\CH Morris.csv
# Processing player: PJ Cummins, Player Name: PJ Cummins, File: player_csv\PJ Cummins.csv
# Processing player: A Mishra, Player Name: A Mishra, File: player_csv\A Mishra.csv
# Processing player: Z Khan, Player Name: Z Khan, File: player_csv\Z Khan.csv
# Processing player: AM Rahane, Player Name: AM Rahane, File: player_csv\AM Rahane.csv
# Processing player: RA Tripathi, Player Name: RA Tripathi, File: player_csv\RA Tripathi.csv
# Processing player: SPD Smith, Player Name: SPD Smith, File: player_csv\SPD Smith.csv
# Processing player: MS Dhoni, Player Name: MS Dhoni, File: player_csv\MS Dhoni.csv
# Processing player: BA Stokes, Player Name: BA Stokes, File: player_csv\BA Stokes.csv
# Processing player: MK Tiwary, Player Name: MK Tiwary, File: player_csv\MK Tiwary.csv
# Processing player: DT Christian, Player Name: DT Christian, File: player_csv\DT Christian.csv
# Processing player: Washington Sundar, Player Name: Washington Sundar, File: player_csv\Washington Sundar.csv
# Processing player: SN Thakur, Player Name: SN Thakur, File: player_csv\SN Thakur.csv
# Processing player: JD Unadkat, Player Name: JD Unadkat, File: player_csv\JD Unadkat.csv
# Processing player: Imran Tahir, Player Name: Imran Tahir, File: player_csv\Imran Tahir.csv
# Processing player: DA Warner, Player Name: DA Warner, File: player_csv\DA Warner.csv
# Processing player: S Dhawan, Player Name: S Dhawan, File: player_csv\S Dhawan.csv
# Processing player: KS Williamson, Player Name: KS Williamson, File: player_csv\KS Williamson.csv
# Processing player: MC Henriques, Player Name: MC Henriques, File: player_csv\MC Henriques.csv
# Processing player: DJ Hooda, Player Name: DJ Hooda, File: player_csv\DJ Hooda.csv
# Processing player: NV Ojha, Player Name: NV Ojha, File: player_csv\NV Ojha.csv
# Processing player: Bipul Sharma, Player Name: Bipul Sharma, File: player_csv\Bipul Sharma.csv
# Processing player: B Kumar, Player Name: B Kumar, File: player_csv\B Kumar.csv
# Processing player: Rashid Khan, Player Name: Rashid Khan, File: player_csv\Rashid Khan.csv
# Processing player: Mohammed Siraj, Player Name: Mohammed Siraj, File: player_csv\Mohammed Siraj.csv
# Processing player: S Kaul, Player Name: S Kaul, File: player_csv\S Kaul.csv
# Processing player: V Shankar, Player Name: V Shankar, File: player_csv\V Shankar.csv
# ...
# Processing player: MC Henriques, Player Name: MC Henriques, File: player_csv\MC Henriques.csv
# Processing player: EJG Morgan, Player Name: EJG Morgan, File: player_csv\EJG Morgan.csv
# Processing player: NV Ojha, Player Name: NV Ojha, File: player_csv\NV Ojha.csv
# Processing player: B Kumar, Player Name: B Kumar, File: player_csv\B Kumar.csv
# Processing player: KV Sharma, Player Name: KV Sharma, File: player_csv\KV Sharma.csv
# Processing player: Mustafizur Rahman, Player Name: Mustafizur Rahman, File: player_csv\Mustafizur Rahman.csv
# Processing player: BB Sran, Player Name: BB Sran, File: player_csv\BB Sran.csv
# Processing player: AM Rahane, Player Name: AM Rahane, File: player_csv\AM Rahane.csv
# Processing player: UT Khawaja, Player Name: UT Khawaja, File: player_csv\UT Khawaja.csv
# Processing player: GJ Bailey, Player Name: GJ Bailey, File: player_csv\GJ Bailey.csv
# Processing player: SS Tiwary, Player Name: SS Tiwary, File: player_csv\SS Tiwary.csv
# Processing player: MS Dhoni, Player Name: MS Dhoni, File: player_csv\MS Dhoni.csv
# Processing player: IK Pathan, Player Name: IK Pathan, File: player_csv\IK Pathan.csv
# Processing player: NLTC Perera, Player Name: NLTC Perera, File: player_csv\NLTC Perera.csv
# Processing player: R Ashwin, Player Name: R Ashwin, File: player_csv\R Ashwin.csv
# Processing player: A Zampa, Player Name: A Zampa, File: player_csv\A Zampa.csv
# Processing player: AB Dinda, Player Name: AB Dinda, File: player_csv\AB Dinda.csv
# Processing player: DL Chahar, Player Name: DL Chahar, File: player_csv\DL Chahar.csv
# Processing player: HM Amla, Player Name: HM Amla, File: player_csv\HM Amla.csv
# Processing player: M Vijay, Player Name: M Vijay, File: player_csv\M Vijay.csv
# Processing player: WP Saha, Player Name: WP Saha, File: player_csv\WP Saha.csv
# Processing player: Gurkeerat Singh, Player Name: Gurkeerat Singh, File: player_csv\Gurkeerat Singh.csv
# Processing player: DA Miller, Player Name: DA Miller, File: player_csv\DA Miller.csv
# Processing player: F Behardien, Player Name: F Behardien, File: player_csv\F Behardien.csv
# Processing player: AR Patel, Player Name: AR Patel, File: player_csv\AR Patel.csv
# Processing player: R Dhawan, Player Name: R Dhawan, File: player_csv\R Dhawan.csv
# Processing player: RA Jadeja, Player Name: RA Jadeja, File: player_csv\RA Jadeja.csv
# Processing player: DJ Bravo, Player Name: DJ Bravo, File: player_csv\DJ Bravo.csv
# Processing player: DS Kulkarni, Player Name: DS Kulkarni, File: player_csv\DS Kulkarni.csv
# Processing player: P Kumar, Player Name: P Kumar, File: player_csv\P Kumar.csv
# Processing player: S Kaushik, Player Name: S Kaushik, File: player_csv\S Kaushik.csv
# Processing player: DA Warner, Player Name: DA Warner, File: player_csv\DA Warner.csv
# Processing player: S Dhawan, Player Name: S Dhawan, File: player_csv\S Dhawan.csv
# Processing player: MC Henriques, Player Name: MC Henriques, File: player_csv\MC Henriques.csv
# Processing player: Yuvraj Singh, Player Name: Yuvraj Singh, File: player_csv\Yuvraj Singh.csv
# Processing player: DJ Hooda, Player Name: DJ Hooda, File: player_csv\DJ Hooda.csv
# Processing player: BCJ Cutting, Player Name: BCJ Cutting, File: player_csv\BCJ Cutting.csv
# Processing player: NV Ojha, Player Name: NV Ojha, File: player_csv\NV Ojha.csv
# Processing player: Bipul Sharma, Player Name: Bipul Sharma, File: player_csv\Bipul Sharma.csv
# Processing player: B Kumar, Player Name: B Kumar, File: player_csv\B Kumar.csv
# Processing player: BB Sran, Player Name: BB Sran, File: player_csv\BB Sran.csv
# Processing player: TA Boult, Player Name: TA Boult, File: player_csv\TA Boult.csv
# Processing player: CH Gayle, Player Name: CH Gayle, File: player_csv\CH Gayle.csv
# Processing player: V Kohli, Player Name: V Kohli, File: player_csv\V Kohli.csv
# Processing player: AB de Villiers, Player Name: AB de Villiers, File: player_csv\AB de Villiers.csv
# Processing player: KL Rahul, Player Name: KL Rahul, File: player_csv\KL Rahul.csv
# Processing player: SR Watson, Player Name: SR Watson, File: player_csv\SR Watson.csv
# Processing player: Sachin Baby, Player Name: Sachin Baby, File: player_csv\Sachin Baby.csv
# Processing player: STR Binny, Player Name: STR Binny, File: player_csv\STR Binny.csv
# Processing player: CJ Jordan, Player Name: CJ Jordan, File: player_csv\CJ Jordan.csv
# Processing player: Iqbal Abdulla, Player Name: Iqbal Abdulla, File: player_csv\Iqbal Abdulla.csv
# Processing player: S Aravind, Player Name: S Aravind, File: player_csv\S Aravind.csv
# Processing player: YS Chahal, Player Name: YS Chahal, File: player_csv\YS Chahal.csv
# Processing player: DA Warner, Player Name: DA Warner, File: player_csv\DA Warner.csv
# Processing player: S Dhawan, Player Name: S Dhawan, File: player_csv\S Dhawan.csv
# Processing player: MC Henriques, Player Name: MC Henriques, File: player_csv\MC Henriques.csv
# Processing player: Yuvraj Singh, Player Name: Yuvraj Singh, File: player_csv\Yuvraj Singh.csv
# Processing player: DJ Hooda, Player Name: DJ Hooda, File: player_csv\DJ Hooda.csv
# Processing player: BCJ Cutting, Player Name: BCJ Cutting, File: player_csv\BCJ Cutting.csv
# Processing player: NV Ojha, Player Name: NV Ojha, File: player_csv\NV Ojha.csv
# Processing player: Bipul Sharma, Player Name: Bipul Sharma, File: player_csv\Bipul Sharma.csv
# Processing player: B Kumar, Player Name: B Kumar, File: player_csv\B Kumar.csv
# Processing player: BB Sran, Player Name: BB Sran, File: player_csv\BB Sran.csv
# Processing player: Mustafizur Rahman, Player Name: Mustafizur Rahman, File: player_csv\Mustafizur Rahman.csv

# %%
import os
import pandas as pd

def find_outliers_in_folder(folder_path, column_name):
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".csv"):
            file_path = os.path.join(folder_path, file_name)

            try:
                df = pd.read_csv(file_path) 

                non_string_rows = df[~df[column_name].apply(lambda x: isinstance(x, str))]

                if not non_string_rows.empty:
                    print(f"Outliers found in file '{file_name}':")
                    for _, row in non_string_rows.iterrows():
                        print(f" - Player ID: {row[column_name]}")
                    print("-" * 50)
            except Exception as e:
                print(f"Error processing file '{file_name}': {e}")

# Example usage
folder_path = "player_csv"
# column_name = "player_id"

# find_outliers_in_folder(folder_path, column_name)


def check_for_empty_cells(file_path):
    """Checks if a given CSV file has any empty cells.

    Args:
        file_path (str): Path to the CSV file.

    Returns:
        bool: True if the file has empty cells, False otherwise.
    """

    df = pd.read_csv(file_path)
    if df.isnull().values.any():
        return True
    else:
        return False

# Example usage:
for file_name in os.listdir(folder_path):
        if file_name.endswith(".csv"):
            file_path = os.path.join(folder_path, file_name)
            # file_path = "your_data.csv"
            has_empty_cells = check_for_empty_cells(file_path)

            if has_empty_cells:
                print(f"The {file_path}CSV file has empty cells.")
            # else:
            #     print("The CSV file has no empty cells.")
# Out:
# The player_csv\A Ashish Reddy.csvCSV file has empty cells.
# The player_csv\A Badoni.csvCSV file has empty cells.
# The player_csv\A Chandila.csvCSV file has empty cells.
# The player_csv\A Chopra.csvCSV file has empty cells.
# The player_csv\A Choudhary.csvCSV file has empty cells.
# The player_csv\A Dananjaya.csvCSV file has empty cells.
# The player_csv\A Flintoff.csvCSV file has empty cells.
# The player_csv\A Kamboj.csvCSV file has empty cells.
# The player_csv\A Kumble.csvCSV file has empty cells.
# The player_csv\A Manohar.csvCSV file has empty cells.
# The player_csv\A Mishra.csvCSV file has empty cells.
# The player_csv\A Mithun.csvCSV file has empty cells.
# The player_csv\A Mukund.csvCSV file has empty cells.
# The player_csv\A Nehra.csvCSV file has empty cells.
# The player_csv\A Nel.csvCSV file has empty cells.
# The player_csv\A Nortje.csvCSV file has empty cells.
# The player_csv\A Raghuvanshi.csvCSV file has empty cells.
# The player_csv\A Singh.csvCSV file has empty cells.
# The player_csv\A Symonds.csvCSV file has empty cells.
# The player_csv\A Tomar.csvCSV file has empty cells.
# The player_csv\A Uniyal.csvCSV file has empty cells.
# The player_csv\A Zampa.csvCSV file has empty cells.
# The player_csv\AA Bilakhia.csvCSV file has empty cells.
# The player_csv\AA Chavan.csvCSV file has empty cells.
# The player_csv\AA Jhunjhunwala.csvCSV file has empty cells.
# The player_csv\AA Kazi.csvCSV file has empty cells.
# The player_csv\AA Kulkarni.csvCSV file has empty cells.
# The player_csv\AA Noffke.csvCSV file has empty cells.
# The player_csv\AB Agarkar.csvCSV file has empty cells.
# The player_csv\AB Barath.csvCSV file has empty cells.
# The player_csv\AB de Villiers.csvCSV file has empty cells.
# The player_csv\AB Dinda.csvCSV file has empty cells.
# The player_csv\AB McDonald.csvCSV file has empty cells.
# The player_csv\Abdul Basith.csvCSV file has empty cells.
# The player_csv\Abdul Samad.csvCSV file has empty cells.
# The player_csv\Abdur Razzak.csvCSV file has empty cells.
# The player_csv\Abhishek Sharma.csvCSV file has empty cells.
# The player_csv\Abishek Porel.csvCSV file has empty cells.
# The player_csv\AC Blizzard.csvCSV file has empty cells.
# The player_csv\AC Gilchrist.csvCSV file has empty cells.
# The player_csv\AC Thomas.csvCSV file has empty cells.
# The player_csv\AC Voges.csvCSV file has empty cells.
# The player_csv\AD Hales.csvCSV file has empty cells.
# The player_csv\AD Mascarenhas.csvCSV file has empty cells.
# The player_csv\AD Mathews.csvCSV file has empty cells.
# The player_csv\AD Nath.csvCSV file has empty cells.
# The player_csv\AD Russell.csvCSV file has empty cells.
# The player_csv\AF Milne.csvCSV file has empty cells.
# The player_csv\AG Murtaza.csvCSV file has empty cells.
# The player_csv\AG Paunikar.csvCSV file has empty cells.
# The player_csv\AJ Finch.csvCSV file has empty cells.
# The player_csv\AJ Hosein.csvCSV file has empty cells.
# The player_csv\AJ Turner.csvCSV file has empty cells.
# The player_csv\AJ Tye.csvCSV file has empty cells.
# The player_csv\AK Markram.csvCSV file has empty cells.
# The player_csv\Akash Deep.csvCSV file has empty cells.
# The player_csv\Akash Madhwal.csvCSV file has empty cells.
# The player_csv\Akash Singh.csvCSV file has empty cells.
# The player_csv\AL Menaria.csvCSV file has empty cells.
# The player_csv\AM Nayar.csvCSV file has empty cells.
# The player_csv\AM Rahane.csvCSV file has empty cells.
# The player_csv\AM Salvi.csvCSV file has empty cells.
# The player_csv\Aman Hakim Khan.csvCSV file has empty cells.
# The player_csv\AN Ahmed.csvCSV file has empty cells.
# The player_csv\AN Ghosh.csvCSV file has empty cells.
# The player_csv\Anand Rajan.csvCSV file has empty cells.
# The player_csv\Anirudh Singh.csvCSV file has empty cells.
# The player_csv\Ankit Sharma.csvCSV file has empty cells.
# The player_csv\Ankit Soni.csvCSV file has empty cells.
# The player_csv\Anmolpreet Singh.csvCSV file has empty cells.
# The player_csv\Anuj Rawat.csvCSV file has empty cells.
# The player_csv\Anureet Singh.csvCSV file has empty cells.
# The player_csv\AP Dole.csvCSV file has empty cells.
# The player_csv\AP Majumdar.csvCSV file has empty cells.
# The player_csv\AP Tare.csvCSV file has empty cells.
# The player_csv\AR Bawne.csvCSV file has empty cells.
# The player_csv\AR Patel.csvCSV file has empty cells.
# The player_csv\Arjun Tendulkar.csvCSV file has empty cells.
# The player_csv\Arshad Khan (2).csvCSV file has empty cells.
# The player_csv\Arshad Khan.csvCSV file has empty cells.
# The player_csv\Arshdeep Singh.csvCSV file has empty cells.
# The player_csv\AS Joseph.csvCSV file has empty cells.
# The player_csv\AS Rajpoot.csvCSV file has empty cells.
# The player_csv\AS Raut.csvCSV file has empty cells.
# The player_csv\AS Roy.csvCSV file has empty cells.
# The player_csv\AS Yadav.csvCSV file has empty cells.
# The player_csv\Ashutosh Sharma.csvCSV file has empty cells.
# The player_csv\AT Carey.csvCSV file has empty cells.
# The player_csv\AT Rayudu.csvCSV file has empty cells.
# The player_csv\Atharva Taide.csvCSV file has empty cells.
# The player_csv\AU Rashid.csvCSV file has empty cells.
# The player_csv\AUK Pathan.csvCSV file has empty cells.
# The player_csv\AV Wankhade.csvCSV file has empty cells.
# The player_csv\Avesh Khan.csvCSV file has empty cells.
# The player_csv\Azhar Mahmood.csvCSV file has empty cells.
# The player_csv\Azmatullah Omarzai.csvCSV file has empty cells.
# The player_csv\B Akhil.csvCSV file has empty cells.
# The player_csv\B Aparajith.csvCSV file has empty cells.
# The player_csv\B Chipli.csvCSV file has empty cells.
# The player_csv\B Geeves.csvCSV file has empty cells.
# The player_csv\B Indrajith.csvCSV file has empty cells.
# The player_csv\B Kumar.csvCSV file has empty cells.
# The player_csv\B Laughlin.csvCSV file has empty cells.
# The player_csv\B Lee.csvCSV file has empty cells.
# The player_csv\B Sai Sudharsan.csvCSV file has empty cells.
# The player_csv\B Stanlake.csvCSV file has empty cells.
# The player_csv\B Sumanth.csvCSV file has empty cells.
# The player_csv\BA Bhatt.csvCSV file has empty cells.
# The player_csv\BA Stokes.csvCSV file has empty cells.
# The player_csv\Basil Thampi.csvCSV file has empty cells.
# The player_csv\BAW Mendis.csvCSV file has empty cells.
# The player_csv\BB McCullum.csvCSV file has empty cells.
# The player_csv\BB Samantray.csvCSV file has empty cells.
# The player_csv\BB Sran.csvCSV file has empty cells.
# The player_csv\BCJ Cutting.csvCSV file has empty cells.
# The player_csv\BE Hendricks.csvCSV file has empty cells.
# The player_csv\Bipul Sharma.csvCSV file has empty cells.
# The player_csv\BJ Haddin.csvCSV file has empty cells.
# The player_csv\BJ Hodge.csvCSV file has empty cells.
# The player_csv\BJ Rohrer.csvCSV file has empty cells.
# The player_csv\BMAJ Mendis.csvCSV file has empty cells.
# The player_csv\BR Dunk.csvCSV file has empty cells.
# The player_csv\BR Sharath.csvCSV file has empty cells.
# The player_csv\BW Hilfenhaus.csvCSV file has empty cells.
# The player_csv\C de Grandhomme.csvCSV file has empty cells.
# The player_csv\C Ganapathy.csvCSV file has empty cells.
# The player_csv\C Green.csvCSV file has empty cells.
# The player_csv\C Madan.csvCSV file has empty cells.
# The player_csv\C Munro.csvCSV file has empty cells.
# The player_csv\C Nanda.csvCSV file has empty cells.
# The player_csv\C Sakariya.csvCSV file has empty cells.
# The player_csv\CA Ingram.csvCSV file has empty cells.
# The player_csv\CA Lynn.csvCSV file has empty cells.
# The player_csv\CA Pujara.csvCSV file has empty cells.
# The player_csv\CH Gayle.csvCSV file has empty cells.
# The player_csv\CH Morris.csvCSV file has empty cells.
# The player_csv\CJ Anderson.csvCSV file has empty cells.
# The player_csv\CJ Dala.csvCSV file has empty cells.
# The player_csv\CJ Ferguson.csvCSV file has empty cells.
# The player_csv\CJ Green.csvCSV file has empty cells.
# The player_csv\CJ Jordan.csvCSV file has empty cells.
# The player_csv\CJ McKay.csvCSV file has empty cells.
# The player_csv\CK Kapugedera.csvCSV file has empty cells.
# The player_csv\CK Langeveldt.csvCSV file has empty cells.
# The player_csv\CL White.csvCSV file has empty cells.
# The player_csv\CM Gautam.csvCSV file has empty cells.
# The player_csv\CR Brathwaite.csvCSV file has empty cells.
# The player_csv\CR Woakes.csvCSV file has empty cells.
# The player_csv\CRD Fernando.csvCSV file has empty cells.
# The player_csv\CV Varun.csvCSV file has empty cells.
# The player_csv\D Brevis.csvCSV file has empty cells.
# The player_csv\D du Preez.csvCSV file has empty cells.
# The player_csv\D Ferreira.csvCSV file has empty cells.
# The player_csv\D Jansen.csvCSV file has empty cells.
# The player_csv\D Kalyankrishna.csvCSV file has empty cells.
# The player_csv\D Padikkal.csvCSV file has empty cells.
# The player_csv\D Pretorius.csvCSV file has empty cells.
# The player_csv\D Salunkhe.csvCSV file has empty cells.
# The player_csv\D Wiese.csvCSV file has empty cells.
# The player_csv\DA Miller.csvCSV file has empty cells.
# The player_csv\DA Warner.csvCSV file has empty cells.
# The player_csv\DAJ Bracewell.csvCSV file has empty cells.
# The player_csv\DB Das.csvCSV file has empty cells.
# The player_csv\DB Ravi Teja.csvCSV file has empty cells.
# The player_csv\DE Bollinger.csvCSV file has empty cells.
# The player_csv\DG Nalkande.csvCSV file has empty cells.
# The player_csv\DH Yagnik.csvCSV file has empty cells.
# The player_csv\Dhruv Jurel.csvCSV file has empty cells.
# The player_csv\DJ Bravo.csvCSV file has empty cells.
# The player_csv\DJ Harris.csvCSV file has empty cells.
# The player_csv\DJ Hooda.csvCSV file has empty cells.
# The player_csv\DJ Hussey.csvCSV file has empty cells.
# The player_csv\DJ Jacobs.csvCSV file has empty cells.
# The player_csv\DJ Malan.csvCSV file has empty cells.
# The player_csv\DJ Mitchell.csvCSV file has empty cells.
# The player_csv\DJ Muthuswami.csvCSV file has empty cells.
# The player_csv\DJ Thornely.csvCSV file has empty cells.
# The player_csv\DJ Willey.csvCSV file has empty cells.
# The player_csv\DJG Sammy.csvCSV file has empty cells.
# The player_csv\DJM Short.csvCSV file has empty cells.
# The player_csv\DL Chahar.csvCSV file has empty cells.
# The player_csv\DL Vettori.csvCSV file has empty cells.
# The player_csv\DM Bravo.csvCSV file has empty cells.
# The player_csv\DNT Zoysa.csvCSV file has empty cells.
# The player_csv\DP Conway.csvCSV file has empty cells.
# The player_csv\DP Nannes.csvCSV file has empty cells.
# The player_csv\DP Vijaykumar.csvCSV file has empty cells.
# The player_csv\DPMD Jayawardene.csvCSV file has empty cells.
# The player_csv\DR Martyn.csvCSV file has empty cells.
# The player_csv\DR Sams.csvCSV file has empty cells.
# The player_csv\DR Shorey.csvCSV file has empty cells.
# The player_csv\DR Smith.csvCSV file has empty cells.
# The player_csv\DS Kulkarni.csvCSV file has empty cells.
# The player_csv\DS Lehmann.csvCSV file has empty cells.
# The player_csv\DT Christian.csvCSV file has empty cells.
# The player_csv\DT Patil.csvCSV file has empty cells.
# The player_csv\DW Steyn.csvCSV file has empty cells.
# The player_csv\E Lewis.csvCSV file has empty cells.
# The player_csv\EJG Morgan.csvCSV file has empty cells.
# The player_csv\ER Dwivedi.csvCSV file has empty cells.
# The player_csv\F Behardien.csvCSV file has empty cells.
# The player_csv\F du Plessis.csvCSV file has empty cells.
# The player_csv\FA Allen.csvCSV file has empty cells.
# The player_csv\Fazalhaq Farooqi.csvCSV file has empty cells.
# The player_csv\FH Edwards.csvCSV file has empty cells.
# The player_csv\FY Fazal.csvCSV file has empty cells.
# The player_csv\G Coetzee.csvCSV file has empty cells.
# The player_csv\G Gambhir.csvCSV file has empty cells.
# The player_csv\Gagandeep Singh.csvCSV file has empty cells.
# The player_csv\GB Hogg.csvCSV file has empty cells.
# The player_csv\GC Smith.csvCSV file has empty cells.
# The player_csv\GC Viljoen.csvCSV file has empty cells.
# The player_csv\GD McGrath.csvCSV file has empty cells.
# The player_csv\GD Phillips.csvCSV file has empty cells.
# The player_csv\GH Vihari.csvCSV file has empty cells.
# The player_csv\GHS Garton.csvCSV file has empty cells.
# The player_csv\GJ Bailey.csvCSV file has empty cells.
# The player_csv\GJ Maxwell.csvCSV file has empty cells.
# The player_csv\GR Napier.csvCSV file has empty cells.
# The player_csv\GS Sandhu.csvCSV file has empty cells.
# The player_csv\Gulbadin Naib.csvCSV file has empty cells.
# The player_csv\Gurkeerat Singh.csvCSV file has empty cells.
# The player_csv\Gurnoor Brar.csvCSV file has empty cells.
# The player_csv\H Das.csvCSV file has empty cells.
# The player_csv\H Klaasen.csvCSV file has empty cells.
# The player_csv\H Sharma.csvCSV file has empty cells.
# The player_csv\Harbhajan Singh.csvCSV file has empty cells.
# The player_csv\Harmeet Singh.csvCSV file has empty cells.
# The player_csv\Harpreet Brar.csvCSV file has empty cells.
# The player_csv\Harpreet Singh.csvCSV file has empty cells.
# The player_csv\Harshit Rana.csvCSV file has empty cells.
# The player_csv\HC Brook.csvCSV file has empty cells.
# The player_csv\HE van der Dussen.csvCSV file has empty cells.
# The player_csv\HF Gurney.csvCSV file has empty cells.
# The player_csv\HH Gibbs.csvCSV file has empty cells.
# The player_csv\HH Pandya.csvCSV file has empty cells.
# The player_csv\HM Amla.csvCSV file has empty cells.
# The player_csv\HR Shokeen.csvCSV file has empty cells.
# The player_csv\HV Patel.csvCSV file has empty cells.
# The player_csv\I Malhotra.csvCSV file has empty cells.
# The player_csv\I Sharma.csvCSV file has empty cells.
# The player_csv\I Udana.csvCSV file has empty cells.
# The player_csv\IC Pandey.csvCSV file has empty cells.
# The player_csv\IC Porel.csvCSV file has empty cells.
# The player_csv\IK Pathan.csvCSV file has empty cells.
# The player_csv\Imran Tahir.csvCSV file has empty cells.
# The player_csv\Iqbal Abdulla.csvCSV file has empty cells.
# The player_csv\IR Jaggi.csvCSV file has empty cells.
# The player_csv\IS Sodhi.csvCSV file has empty cells.
# The player_csv\Ishan Kishan.csvCSV file has empty cells.
# The player_csv\J Arunkumar.csvCSV file has empty cells.
# The player_csv\J Botha.csvCSV file has empty cells.
# The player_csv\J Fraser-McGurk.csvCSV file has empty cells.
# The player_csv\J Little.csvCSV file has empty cells.
# The player_csv\J Suchith.csvCSV file has empty cells.
# The player_csv\J Syed Mohammad.csvCSV file has empty cells.
# The player_csv\J Theron.csvCSV file has empty cells.
# The player_csv\J Yadav.csvCSV file has empty cells.
# The player_csv\JA Morkel.csvCSV file has empty cells.
# The player_csv\JA Richardson.csvCSV file has empty cells.
# The player_csv\Jalaj S Saxena.csvCSV file has empty cells.
# The player_csv\Jaskaran Singh.csvCSV file has empty cells.
# The player_csv\JC Archer.csvCSV file has empty cells.
# The player_csv\JC Buttler.csvCSV file has empty cells.
# The player_csv\JD Ryder.csvCSV file has empty cells.
# The player_csv\JD Unadkat.csvCSV file has empty cells.
# The player_csv\JDP Oram.csvCSV file has empty cells.
# The player_csv\JDS Neesham.csvCSV file has empty cells.
# The player_csv\JE Root.csvCSV file has empty cells.
# The player_csv\JE Taylor.csvCSV file has empty cells.
# The player_csv\JEC Franklin.csvCSV file has empty cells.
# The player_csv\JH Kallis.csvCSV file has empty cells.
# The player_csv\JJ Bumrah.csvCSV file has empty cells.
# The player_csv\JJ Roy.csvCSV file has empty cells.
# The player_csv\JJ van der Wath.csvCSV file has empty cells.
# The player_csv\JL Denly.csvCSV file has empty cells.
# The player_csv\JL Pattinson.csvCSV file has empty cells.
# The player_csv\JM Bairstow.csvCSV file has empty cells.
# The player_csv\JM Kemp.csvCSV file has empty cells.
# The player_csv\JM Sharma.csvCSV file has empty cells.
# The player_csv\JO Holder.csvCSV file has empty cells.
# The player_csv\Joginder Sharma.csvCSV file has empty cells.
# The player_csv\JP Behrendorff.csvCSV file has empty cells.
# The player_csv\JP Duminy.csvCSV file has empty cells.
# The player_csv\JP Faulkner.csvCSV file has empty cells.
# The player_csv\JPR Scantlebury-Searles.csvCSV file has empty cells.
# The player_csv\JR Hazlewood.csvCSV file has empty cells.
# The player_csv\JR Hopes.csvCSV file has empty cells.
# The player_csv\JR Philippe.csvCSV file has empty cells.
# The player_csv\JW Hastings.csvCSV file has empty cells.
# The player_csv\K Goel.csvCSV file has empty cells.
# The player_csv\K Gowtham.csvCSV file has empty cells.
# The player_csv\K Kartikeya.csvCSV file has empty cells.
# The player_csv\K Khejroliya.csvCSV file has empty cells.
# The player_csv\K Rabada.csvCSV file has empty cells.
# The player_csv\K Santokie.csvCSV file has empty cells.
# The player_csv\K Upadhyay.csvCSV file has empty cells.
# The player_csv\K Yadav.csvCSV file has empty cells.
# The player_csv\KA Jamieson.csvCSV file has empty cells.
# The player_csv\KA Maharaj.csvCSV file has empty cells.
# The player_csv\KA Pollard.csvCSV file has empty cells.
# The player_csv\KAJ Roach.csvCSV file has empty cells.
# The player_csv\Kamran Akmal.csvCSV file has empty cells.
# The player_csv\Kamran Khan.csvCSV file has empty cells.
# The player_csv\Karanveer Singh.csvCSV file has empty cells.
# The player_csv\Kartik Tyagi.csvCSV file has empty cells.
# The player_csv\KB Arun Karthik.csvCSV file has empty cells.
# The player_csv\KC Cariappa.csvCSV file has empty cells.
# The player_csv\KC Sangakkara.csvCSV file has empty cells.
# The player_csv\KD Karthik.csvCSV file has empty cells.
# The player_csv\KH Devdhar.csvCSV file has empty cells.
# The player_csv\KH Pandya.csvCSV file has empty cells.
# The player_csv\KJ Abbott.csvCSV file has empty cells.
# The player_csv\KK Ahmed.csvCSV file has empty cells.
# The player_csv\KK Cooper.csvCSV file has empty cells.
# The player_csv\KK Nair.csvCSV file has empty cells.
# The player_csv\KL Nagarkoti.csvCSV file has empty cells.
# The player_csv\KL Rahul.csvCSV file has empty cells.
# The player_csv\KM Asif.csvCSV file has empty cells.
# The player_csv\KM Jadhav.csvCSV file has empty cells.
# The player_csv\KMA Paul.csvCSV file has empty cells.
# The player_csv\KMDN Kulasekara.csvCSV file has empty cells.
# The player_csv\KP Appanna.csvCSV file has empty cells.
# The player_csv\KP Pietersen.csvCSV file has empty cells.
# The player_csv\KR Mayers.csvCSV file has empty cells.
# The player_csv\KR Sen.csvCSV file has empty cells.
# The player_csv\KS Bharat.csvCSV file has empty cells.
# The player_csv\KS Sharma.csvCSV file has empty cells.
# The player_csv\KS Williamson.csvCSV file has empty cells.
# The player_csv\KT Maphaka.csvCSV file has empty cells.
# The player_csv\Kuldeep Yadav.csvCSV file has empty cells.
# The player_csv\Kumar Kushagra.csvCSV file has empty cells.
# The player_csv\KV Sharma.csvCSV file has empty cells.
# The player_csv\KW Richardson.csvCSV file has empty cells.
# The player_csv\L Ablish.csvCSV file has empty cells.
# The player_csv\L Balaji.csvCSV file has empty cells.
# The player_csv\L Ngidi.csvCSV file has empty cells.
# The player_csv\L Ronchi.csvCSV file has empty cells.
# The player_csv\L Wood.csvCSV file has empty cells.
# The player_csv\LA Carseldine.csvCSV file has empty cells.
# The player_csv\LA Pomersbach.csvCSV file has empty cells.
# The player_csv\Lalit Yadav.csvCSV file has empty cells.
# The player_csv\LB Williams.csvCSV file has empty cells.
# The player_csv\LE Plunkett.csvCSV file has empty cells.
# The player_csv\LH Ferguson.csvCSV file has empty cells.
# The player_csv\LI Meriwala.csvCSV file has empty cells.
# The player_csv\Liton Das.csvCSV file has empty cells.
# The player_csv\LJ Wright.csvCSV file has empty cells.
# The player_csv\LMP Simmons.csvCSV file has empty cells.
# The player_csv\LPC Silva.csvCSV file has empty cells.
# The player_csv\LR Shukla.csvCSV file has empty cells.
# The player_csv\LRPL Taylor.csvCSV file has empty cells.
# The player_csv\LS Livingstone.csvCSV file has empty cells.
# The player_csv\M Ashwin.csvCSV file has empty cells.
# The player_csv\M de Lange.csvCSV file has empty cells.
# The player_csv\M Jansen.csvCSV file has empty cells.
# The player_csv\M Kaif.csvCSV file has empty cells.
# The player_csv\M Kartik.csvCSV file has empty cells.
# The player_csv\M Klinger.csvCSV file has empty cells.
# The player_csv\M Manhas.csvCSV file has empty cells.
# The player_csv\M Markande.csvCSV file has empty cells.
# The player_csv\M Morkel.csvCSV file has empty cells.
# The player_csv\M Muralitharan.csvCSV file has empty cells.
# The player_csv\M Ntini.csvCSV file has empty cells.
# The player_csv\M Pathirana.csvCSV file has empty cells.
# The player_csv\M Prasidh Krishna.csvCSV file has empty cells.
# The player_csv\M Rawat.csvCSV file has empty cells.
# The player_csv\M Shahrukh Khan.csvCSV file has empty cells.
# The player_csv\M Siddharth.csvCSV file has empty cells.
# The player_csv\M Theekshana.csvCSV file has empty cells.
# The player_csv\M Vijay.csvCSV file has empty cells.
# The player_csv\M Vohra.csvCSV file has empty cells.
# The player_csv\MA Agarwal.csvCSV file has empty cells.
# The player_csv\MA Khote.csvCSV file has empty cells.
# The player_csv\MA Starc.csvCSV file has empty cells.
# The player_csv\MA Wood.csvCSV file has empty cells.
# The player_csv\Mandeep Singh.csvCSV file has empty cells.
# The player_csv\Mashrafe Mortaza.csvCSV file has empty cells.
# The player_csv\Mayank Dagar.csvCSV file has empty cells.
# The player_csv\MB Parmar.csvCSV file has empty cells.
# The player_csv\MC Henriques.csvCSV file has empty cells.
# The player_csv\MC Juneja.csvCSV file has empty cells.
# The player_csv\MD Mishra.csvCSV file has empty cells.
# The player_csv\MD Shanaka.csvCSV file has empty cells.
# The player_csv\MDKJ Perera.csvCSV file has empty cells.
# The player_csv\MEK Hussey.csvCSV file has empty cells.
# The player_csv\MF Maharoof.csvCSV file has empty cells.
# The player_csv\MG Bracewell.csvCSV file has empty cells.
# The player_csv\MG Johnson.csvCSV file has empty cells.
# The player_csv\MG Neser.csvCSV file has empty cells.
# The player_csv\Milind Kumar.csvCSV file has empty cells.
# The player_csv\Misbah-ul-Haq.csvCSV file has empty cells.
# The player_csv\MJ Clarke.csvCSV file has empty cells.
# The player_csv\MJ Guptill.csvCSV file has empty cells.
# The player_csv\MJ Henry.csvCSV file has empty cells.
# The player_csv\MJ Lumb.csvCSV file has empty cells.
# The player_csv\MJ McClenaghan.csvCSV file has empty cells.
# The player_csv\MJ Santner.csvCSV file has empty cells.
# The player_csv\MJ Suthar.csvCSV file has empty cells.
# The player_csv\MK Lomror.csvCSV file has empty cells.
# The player_csv\MK Pandey.csvCSV file has empty cells.
# The player_csv\MK Tiwary.csvCSV file has empty cells.
# The player_csv\ML Hayden.csvCSV file has empty cells.
# The player_csv\MM Ali.csvCSV file has empty cells.
# The player_csv\MM Patel.csvCSV file has empty cells.
# The player_csv\MM Sharma.csvCSV file has empty cells.
# The player_csv\MN Samuels.csvCSV file has empty cells.
# The player_csv\MN van Wyk.csvCSV file has empty cells.
# The player_csv\Mohammad Ashraful.csvCSV file has empty cells.
# The player_csv\Mohammad Asif.csvCSV file has empty cells.
# The player_csv\Mohammad Hafeez.csvCSV file has empty cells.
# The player_csv\Mohammad Nabi.csvCSV file has empty cells.
# The player_csv\Mohammed Shami.csvCSV file has empty cells.
# The player_csv\Mohammed Siraj.csvCSV file has empty cells.
# The player_csv\Mohit Rathee.csvCSV file has empty cells.
# The player_csv\Mohsin Khan.csvCSV file has empty cells.
# The player_csv\Monu Kumar.csvCSV file has empty cells.
# The player_csv\MP Stoinis.csvCSV file has empty cells.
# The player_csv\MP Yadav.csvCSV file has empty cells.
# The player_csv\MR Marsh.csvCSV file has empty cells.
# The player_csv\MS Bisla.csvCSV file has empty cells.
# The player_csv\MS Dhoni.csvCSV file has empty cells.
# The player_csv\MS Gony.csvCSV file has empty cells.
# The player_csv\MS Wade.csvCSV file has empty cells.
# The player_csv\Mujeeb Ur Rahman.csvCSV file has empty cells.
# The player_csv\Mukesh Choudhary.csvCSV file has empty cells.
# The player_csv\Mukesh Kumar.csvCSV file has empty cells.
# The player_csv\Mustafizur Rahman.csvCSV file has empty cells.
# The player_csv\MV Boucher.csvCSV file has empty cells.
# The player_csv\MW Short.csvCSV file has empty cells.
# The player_csv\N Burger.csvCSV file has empty cells.
# The player_csv\N Jagadeesan.csvCSV file has empty cells.
# The player_csv\N Pooran.csvCSV file has empty cells.
# The player_csv\N Rana.csvCSV file has empty cells.
# The player_csv\N Saini.csvCSV file has empty cells.
# The player_csv\N Thushara.csvCSV file has empty cells.
# The player_csv\N Wadhera.csvCSV file has empty cells.
# The player_csv\NA Saini.csvCSV file has empty cells.
# The player_csv\Naman Dhir.csvCSV file has empty cells.
# The player_csv\Navdeep Saini.csvCSV file has empty cells.
# The player_csv\Naveen-ul-Haq.csvCSV file has empty cells.
# The player_csv\NB Singh.csvCSV file has empty cells.
# The player_csv\ND Doshi.csvCSV file has empty cells.
# The player_csv\Nithish Kumar Reddy.csvCSV file has empty cells.
# The player_csv\NJ Maddinson.csvCSV file has empty cells.
# The player_csv\NJ Rimmington.csvCSV file has empty cells.
# The player_csv\NK Patel.csvCSV file has empty cells.
# The player_csv\NL McCullum.csvCSV file has empty cells.
# The player_csv\NLTC Perera.csvCSV file has empty cells.
# The player_csv\NM Coulter-Nile.csvCSV file has empty cells.
# The player_csv\Noor Ahmad.csvCSV file has empty cells.
# The player_csv\NS Naik.csvCSV file has empty cells.
# The player_csv\NT Ellis.csvCSV file has empty cells.
# The player_csv\NV Ojha.csvCSV file has empty cells.
# The player_csv\O Thomas.csvCSV file has empty cells.
# The player_csv\OA Shah.csvCSV file has empty cells.
# The player_csv\OC McCoy.csvCSV file has empty cells.
# The player_csv\OF Smith.csvCSV file has empty cells.
# The player_csv\P Amarnath.csvCSV file has empty cells.
# The player_csv\P Awana.csvCSV file has empty cells.
# The player_csv\P Chopra.csvCSV file has empty cells.
# The player_csv\P Dharmani.csvCSV file has empty cells.
# The player_csv\P Dogra.csvCSV file has empty cells.
# The player_csv\P Dubey.csvCSV file has empty cells.
# The player_csv\P Kumar.csvCSV file has empty cells.
# The player_csv\P Negi.csvCSV file has empty cells.
# The player_csv\P Parameswaran.csvCSV file has empty cells.
# The player_csv\P Prasanth.csvCSV file has empty cells.
# The player_csv\P Ray Barman.csvCSV file has empty cells.
# The player_csv\P Sahu.csvCSV file has empty cells.
# The player_csv\P Simran Singh.csvCSV file has empty cells.
# The player_csv\P Suyal.csvCSV file has empty cells.
# The player_csv\PA Patel.csvCSV file has empty cells.
# The player_csv\PA Reddy.csvCSV file has empty cells.
# The player_csv\Pankaj Singh.csvCSV file has empty cells.
# The player_csv\Parvez Rasool.csvCSV file has empty cells.
# The player_csv\PBB Rajapaksa.csvCSV file has empty cells.
# The player_csv\PC Valthaty.csvCSV file has empty cells.
# The player_csv\PD Collingwood.csvCSV file has empty cells.
# The player_csv\PD Salt.csvCSV file has empty cells.
# The player_csv\PH Solanki.csvCSV file has empty cells.
# The player_csv\PJ Cummins.csvCSV file has empty cells.
# The player_csv\PJ Sangwan.csvCSV file has empty cells.
# The player_csv\PK Garg.csvCSV file has empty cells.
# The player_csv\PM Sarvesh Kumar.csvCSV file has empty cells.
# The player_csv\PN Mankad.csvCSV file has empty cells.
# The player_csv\PP Chawla.csvCSV file has empty cells.
# The player_csv\PP Ojha.csvCSV file has empty cells.
# The player_csv\PP Shaw.csvCSV file has empty cells.
# The player_csv\PR Shah.csvCSV file has empty cells.
# The player_csv\PSP Handscomb.csvCSV file has empty cells.
# The player_csv\PV Tambe.csvCSV file has empty cells.
# The player_csv\PVD Chameera.csvCSV file has empty cells.
# The player_csv\PWH de Silva.csvCSV file has empty cells.
# The player_csv\Q de Kock.csvCSV file has empty cells.
# The player_csv\R Ashwin.csvCSV file has empty cells.
# The player_csv\R Bhatia.csvCSV file has empty cells.
# The player_csv\R Bishnoi.csvCSV file has empty cells.
# The player_csv\R Dhawan.csvCSV file has empty cells.
# The player_csv\R Dravid.csvCSV file has empty cells.
# The player_csv\R Goyal.csvCSV file has empty cells.
# The player_csv\R McLaren.csvCSV file has empty cells.
# The player_csv\R Ninan.csvCSV file has empty cells.
# The player_csv\R Parag.csvCSV file has empty cells.
# The player_csv\R Powell.csvCSV file has empty cells.
# The player_csv\R Rampaul.csvCSV file has empty cells.
# The player_csv\R Ravindra.csvCSV file has empty cells.
# The player_csv\R Sai Kishore.csvCSV file has empty cells.
# The player_csv\R Sanjay Yadav.csvCSV file has empty cells.
# The player_csv\R Sathish.csvCSV file has empty cells.
# The player_csv\R Sharma.csvCSV file has empty cells.
# The player_csv\R Shepherd.csvCSV file has empty cells.
# The player_csv\R Shukla.csvCSV file has empty cells.
# The player_csv\R Tewatia.csvCSV file has empty cells.
# The player_csv\R Vinay Kumar.csvCSV file has empty cells.
# The player_csv\RA Bawa.csvCSV file has empty cells.
# The player_csv\RA Jadeja.csvCSV file has empty cells.
# The player_csv\RA Shaikh.csvCSV file has empty cells.
# The player_csv\RA Tripathi.csvCSV file has empty cells.
# The player_csv\Rahmanullah Gurbaz.csvCSV file has empty cells.
# The player_csv\Ramandeep Singh.csvCSV file has empty cells.
# The player_csv\Rashid Khan.csvCSV file has empty cells.
# The player_csv\Rasikh Salam.csvCSV file has empty cells.
# The player_csv\Ravi Bishnoi.csvCSV file has empty cells.
# The player_csv\RD Chahar.csvCSV file has empty cells.
# The player_csv\RD Gaikwad.csvCSV file has empty cells.
# The player_csv\RE Levi.csvCSV file has empty cells.
# The player_csv\RE van der Merwe.csvCSV file has empty cells.
# The player_csv\RG More.csvCSV file has empty cells.
# The player_csv\RG Sharma.csvCSV file has empty cells.
# The player_csv\RJ Gleeson.csvCSV file has empty cells.
# The player_csv\RJ Harris.csvCSV file has empty cells.
# The player_csv\RJ Peterson.csvCSV file has empty cells.
# The player_csv\RJ Quiney.csvCSV file has empty cells.
# The player_csv\RJW Topley.csvCSV file has empty cells.
# The player_csv\RK Bhui.csvCSV file has empty cells.
# The player_csv\RK Singh.csvCSV file has empty cells.
# The player_csv\RM Patidar.csvCSV file has empty cells.
# The player_csv\RN ten Doeschate.csvCSV file has empty cells.
# The player_csv\RP Meredith.csvCSV file has empty cells.
# The player_csv\RP Singh.csvCSV file has empty cells.
# The player_csv\RR Bhatkal.csvCSV file has empty cells.
# The player_csv\RR Bose.csvCSV file has empty cells.
# The player_csv\RR Pant.csvCSV file has empty cells.
# The player_csv\RR Powar.csvCSV file has empty cells.
# The player_csv\RR Raje.csvCSV file has empty cells.
# The player_csv\RR Rossouw.csvCSV file has empty cells.
# The player_csv\RR Sarwan.csvCSV file has empty cells.
# The player_csv\RS Bopara.csvCSV file has empty cells.
# The player_csv\RS Gavaskar.csvCSV file has empty cells.
# The player_csv\RS Hangargekar.csvCSV file has empty cells.
# The player_csv\RS Sodhi.csvCSV file has empty cells.
# The player_csv\RT Ponting.csvCSV file has empty cells.
# The player_csv\RV Gomez.csvCSV file has empty cells.
# The player_csv\RV Patel.csvCSV file has empty cells.
# The player_csv\RV Pawar.csvCSV file has empty cells.
# The player_csv\RV Uthappa.csvCSV file has empty cells.
# The player_csv\RW Price.csvCSV file has empty cells.
# The player_csv\S Anirudha.csvCSV file has empty cells.
# The player_csv\S Aravind.csvCSV file has empty cells.
# The player_csv\S Badree.csvCSV file has empty cells.
# The player_csv\S Badrinath.csvCSV file has empty cells.
# The player_csv\S Chanderpaul.csvCSV file has empty cells.
# The player_csv\S Dhawan.csvCSV file has empty cells.
# The player_csv\S Dube.csvCSV file has empty cells.
# The player_csv\S Gopal.csvCSV file has empty cells.
# The player_csv\S Joseph.csvCSV file has empty cells.
# The player_csv\S Kaul.csvCSV file has empty cells.
# The player_csv\S Kaushik.csvCSV file has empty cells.
# The player_csv\S Ladda.csvCSV file has empty cells.
# The player_csv\S Lamichhane.csvCSV file has empty cells.
# The player_csv\S Midhun.csvCSV file has empty cells.
# The player_csv\S Nadeem.csvCSV file has empty cells.
# The player_csv\S Narwal.csvCSV file has empty cells.
# The player_csv\S Rana.csvCSV file has empty cells.
# The player_csv\S Randiv.csvCSV file has empty cells.
# The player_csv\S Sandeep Warrier.csvCSV file has empty cells.
# The player_csv\S Sohal.csvCSV file has empty cells.
# The player_csv\S Sreesanth.csvCSV file has empty cells.
# The player_csv\S Sriram.csvCSV file has empty cells.
# The player_csv\S Tyagi.csvCSV file has empty cells.
# The player_csv\S Vidyut.csvCSV file has empty cells.
# The player_csv\SA Abbott.csvCSV file has empty cells.
# The player_csv\SA Asnodkar.csvCSV file has empty cells.
# The player_csv\SA Yadav.csvCSV file has empty cells.
# The player_csv\Sachin Baby.csvCSV file has empty cells.
# The player_csv\Salman Butt.csvCSV file has empty cells.
# The player_csv\Sameer Rizvi.csvCSV file has empty cells.
# The player_csv\Sandeep Sharma.csvCSV file has empty cells.
# The player_csv\Sanvir Singh.csvCSV file has empty cells.
# The player_csv\Saurav Chauhan.csvCSV file has empty cells.
# The player_csv\SB Bangar.csvCSV file has empty cells.
# The player_csv\SB Dubey.csvCSV file has empty cells.
# The player_csv\SB Jakati.csvCSV file has empty cells.
# The player_csv\SB Joshi.csvCSV file has empty cells.
# The player_csv\SB Styris.csvCSV file has empty cells.
# The player_csv\SB Wagh.csvCSV file has empty cells.
# The player_csv\SC Ganguly.csvCSV file has empty cells.
# The player_csv\SC Kuggeleijn.csvCSV file has empty cells.
# The player_csv\SD Chitnis.csvCSV file has empty cells.
# The player_csv\SD Hope.csvCSV file has empty cells.
# The player_csv\SD Lad.csvCSV file has empty cells.
# The player_csv\SE Bond.csvCSV file has empty cells.
# The player_csv\SE Marsh.csvCSV file has empty cells.
# The player_csv\SE Rutherford.csvCSV file has empty cells.
# The player_csv\SH Johnson.csvCSV file has empty cells.
# The player_csv\Shahbaz Ahmed.csvCSV file has empty cells.
# The player_csv\Shahid Afridi.csvCSV file has empty cells.
# The player_csv\Shakib Al Hasan.csvCSV file has empty cells.
# The player_csv\Shashank Singh.csvCSV file has empty cells.
# The player_csv\Shivam Mavi.csvCSV file has empty cells.
# The player_csv\Shivam Sharma.csvCSV file has empty cells.
# The player_csv\Shivam Singh.csvCSV file has empty cells.
# The player_csv\Shoaib Ahmed.csvCSV file has empty cells.
# The player_csv\Shoaib Akhtar.csvCSV file has empty cells.
# The player_csv\Shoaib Malik.csvCSV file has empty cells.
# The player_csv\Shubman Gill.csvCSV file has empty cells.
# The player_csv\Sikandar Raza.csvCSV file has empty cells.
# The player_csv\Simarjeet Singh.csvCSV file has empty cells.
# The player_csv\SJ Srivastava.csvCSV file has empty cells.
# The player_csv\SK Raina.csvCSV file has empty cells.
# The player_csv\SK Rasheed.csvCSV file has empty cells.
# The player_csv\SK Trivedi.csvCSV file has empty cells.
# The player_csv\SK Warne.csvCSV file has empty cells.
# The player_csv\SL Malinga.csvCSV file has empty cells.
# The player_csv\SM Boland.csvCSV file has empty cells.
# The player_csv\SM Curran.csvCSV file has empty cells.
# The player_csv\SM Harwood.csvCSV file has empty cells.
# The player_csv\SM Katich.csvCSV file has empty cells.
# The player_csv\SM Pollock.csvCSV file has empty cells.
# The player_csv\SMSM Senanayake.csvCSV file has empty cells.
# The player_csv\SN Khan.csvCSV file has empty cells.
# The player_csv\SN Thakur.csvCSV file has empty cells.
# The player_csv\SO Hetmyer.csvCSV file has empty cells.
# The player_csv\Sohail Tanvir.csvCSV file has empty cells.
# The player_csv\Sonu Yadav.csvCSV file has empty cells.
# The player_csv\SP Fleming.csvCSV file has empty cells.
# The player_csv\SP Goswami.csvCSV file has empty cells.
# The player_csv\SP Jackson.csvCSV file has empty cells.
# The player_csv\SP Narine.csvCSV file has empty cells.
# The player_csv\SPD Smith.csvCSV file has empty cells.
# The player_csv\SR Tendulkar.csvCSV file has empty cells.
# The player_csv\SR Watson.csvCSV file has empty cells.
# The player_csv\SS Agarwal.csvCSV file has empty cells.
# The player_csv\SS Cottrell.csvCSV file has empty cells.
# The player_csv\SS Iyer.csvCSV file has empty cells.
# The player_csv\SS Mundhe.csvCSV file has empty cells.
# The player_csv\SS Prabhudessai.csvCSV file has empty cells.
# The player_csv\SS Sarkar.csvCSV file has empty cells.
# The player_csv\SS Shaikh.csvCSV file has empty cells.
# The player_csv\SS Tiwary.csvCSV file has empty cells.
# The player_csv\SSB Magala.csvCSV file has empty cells.
# The player_csv\ST Jayasuriya.csvCSV file has empty cells.
# The player_csv\STR Binny.csvCSV file has empty cells.
# The player_csv\Subhransu Senapati.csvCSV file has empty cells.
# The player_csv\Sumit Kumar.csvCSV file has empty cells.
# The player_csv\Sunny Gupta.csvCSV file has empty cells.
# The player_csv\Sunny Singh.csvCSV file has empty cells.
# The player_csv\Suyash Sharma.csvCSV file has empty cells.
# The player_csv\SV Samson.csvCSV file has empty cells.
# The player_csv\SW Billings.csvCSV file has empty cells.
# The player_csv\SW Tait.csvCSV file has empty cells.
# The player_csv\Swapnil Singh.csvCSV file has empty cells.
# The player_csv\SZ Mulani.csvCSV file has empty cells.
# The player_csv\T Banton.csvCSV file has empty cells.
# The player_csv\T Henderson.csvCSV file has empty cells.
# The player_csv\T Kohler-Cadmore.csvCSV file has empty cells.
# The player_csv\T Kohli.csvCSV file has empty cells.
# The player_csv\T Mishra.csvCSV file has empty cells.
# The player_csv\T Natarajan.csvCSV file has empty cells.
# The player_csv\T Shamsi.csvCSV file has empty cells.
# The player_csv\T Stubbs.csvCSV file has empty cells.
# The player_csv\T Taibu.csvCSV file has empty cells.
# The player_csv\T Thushara.csvCSV file has empty cells.
# The player_csv\TA Boult.csvCSV file has empty cells.
# The player_csv\Tanay Thyagarajan.csvCSV file has empty cells.
# The player_csv\Tanush Kotian.csvCSV file has empty cells.
# The player_csv\TD Paine.csvCSV file has empty cells.
# The player_csv\Tejas Baroka.csvCSV file has empty cells.
# The player_csv\TG Southee.csvCSV file has empty cells.
# The player_csv\TH David.csvCSV file has empty cells.
# The player_csv\Tilak Varma.csvCSV file has empty cells.
# The player_csv\TK Curran.csvCSV file has empty cells.
# The player_csv\TL Seifert.csvCSV file has empty cells.
# The player_csv\TL Suman.csvCSV file has empty cells.
# The player_csv\TM Dilshan.csvCSV file has empty cells.
# The player_csv\TM Head.csvCSV file has empty cells.
# The player_csv\TM Srivastava.csvCSV file has empty cells.
# The player_csv\TP Sudhindra.csvCSV file has empty cells.
# The player_csv\TR Birt.csvCSV file has empty cells.
# The player_csv\TS Mills.csvCSV file has empty cells.
# The player_csv\TU Deshpande.csvCSV file has empty cells.
# The player_csv\U Kaul.csvCSV file has empty cells.
# The player_csv\UA Birla.csvCSV file has empty cells.
# The player_csv\UBT Chand.csvCSV file has empty cells.
# The player_csv\Umar Gul.csvCSV file has empty cells.
# The player_csv\Umran Malik.csvCSV file has empty cells.
# The player_csv\UT Khawaja.csvCSV file has empty cells.
# The player_csv\UT Yadav.csvCSV file has empty cells.
# The player_csv\V Kaverappa.csvCSV file has empty cells.
# The player_csv\V Kohli.csvCSV file has empty cells.
# The player_csv\V Pratap Singh.csvCSV file has empty cells.
# The player_csv\V Sehwag.csvCSV file has empty cells.
# The player_csv\V Shankar.csvCSV file has empty cells.
# The player_csv\V Viyaskanth.csvCSV file has empty cells.
# The player_csv\VG Arora.csvCSV file has empty cells.
# The player_csv\VH Zol.csvCSV file has empty cells.
# The player_csv\Vijaykumar Vyshak.csvCSV file has empty cells.
# The player_csv\Virat Singh.csvCSV file has empty cells.
# The player_csv\Vishnu Vinod.csvCSV file has empty cells.
# The player_csv\Vivrant Sharma.csvCSV file has empty cells.
# The player_csv\VR Aaron.csvCSV file has empty cells.
# The player_csv\VR Iyer.csvCSV file has empty cells.
# The player_csv\VRV Singh.csvCSV file has empty cells.
# The player_csv\VS Malik.csvCSV file has empty cells.
# The player_csv\VS Yeligati.csvCSV file has empty cells.
# The player_csv\VVS Laxman.csvCSV file has empty cells.
# The player_csv\VY Mahesh.csvCSV file has empty cells.
# The player_csv\W Jaffer.csvCSV file has empty cells.
# The player_csv\WA Mota.csvCSV file has empty cells.
# The player_csv\Washington Sundar.csvCSV file has empty cells.
# The player_csv\WD Parnell.csvCSV file has empty cells.
# The player_csv\WG Jacks.csvCSV file has empty cells.
# The player_csv\WP Saha.csvCSV file has empty cells.
# The player_csv\WPUJC Vaas.csvCSV file has empty cells.
# The player_csv\X Thalaivan Sargunam.csvCSV file has empty cells.
# The player_csv\Y Gnaneswara Rao.csvCSV file has empty cells.
# The player_csv\Y Nagar.csvCSV file has empty cells.
# The player_csv\Y Prithvi Raj.csvCSV file has empty cells.
# The player_csv\Y Venugopal Rao.csvCSV file has empty cells.
# The player_csv\YA Abdulla.csvCSV file has empty cells.
# The player_csv\Yash Dayal.csvCSV file has empty cells.
# The player_csv\Yash Thakur.csvCSV file has empty cells.
# The player_csv\Yashpal Singh.csvCSV file has empty cells.
# The player_csv\YBK Jaiswal.csvCSV file has empty cells.
# The player_csv\YK Pathan.csvCSV file has empty cells.
# The player_csv\Younis Khan.csvCSV file has empty cells.
# The player_csv\YS Chahal.csvCSV file has empty cells.
# The player_csv\Yudhvir Singh.csvCSV file has empty cells.
# The player_csv\Yuvraj Singh.csvCSV file has empty cells.
# The player_csv\YV Dhull.csvCSV file has empty cells.
# The player_csv\YV Takawale.csvCSV file has empty cells.
# The player_csv\Z Khan.csvCSV file has empty cells.

# %%
df = pd.read_csv(file_path)
df = df.rename(columns={"identifier": "player_id"})
df.to_csv(file_path, index=False)

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping


# Directory containing individual player data files
data_folder = 'player_csv'  # Replace with the actual folder path

# Function to compute rolling averages
def compute_rolling_averages(df, player_name, date, column, windows):
    player_data = df[(df['player_name'] == player_name) & (df['date'] < date)].sort_values(by='date')
    averages = []
    for window in windows:
        avg = player_data[column].tail(window).mean()
        averages.append(avg if not np.isnan(avg) else 0)
    overall_avg = player_data[column].mean()
    averages.append(overall_avg if not np.isnan(overall_avg) else 0)
    return averages

# Load all player data from CSV files
player_files = [f for f in os.listdir(data_folder) if f.endswith('.csv')]
features = []
targets = []

windows = [3, 5, 10, 20]

# Loop through each player's data file
for player_file in player_files:
    # print(player_file)
    player_data = pd.read_csv(os.path.join(data_folder, player_file))
    # print(player_data)
    # Loop through each match in the player's data
    for i, row in player_data.iterrows():
        # Compute rolling averages for the current player
        batting_avgs = compute_rolling_averages(player_data, row['player_name'], row['date'], 'batting_points', windows)
        bowling_avgs = compute_rolling_averages(player_data, row['player_name'], row['date'], 'bowling_points', windows)
        fielding_avgs = compute_rolling_averages(player_data, row['player_name'], row['date'], 'fielding_points', windows)
        
        # Now compute rolling averages for the 11 opponents
        opponent_features = []
        for j in range(1, 12):  # opponent columns: player1 to player11
            opponent_name = row[f'player{j}']
            opponent_data = pd.read_csv(os.path.join(data_folder, f'{opponent_name}.csv'))  # Opponent player's data
            
            # Compute rolling averages for the opponent's batting, bowling, and fielding
            opponent_batting_avgs = compute_rolling_averages(opponent_data, opponent_name, row['date'], 'batting_points', windows)
            opponent_bowling_avgs = compute_rolling_averages(opponent_data, opponent_name, row['date'], 'bowling_points', windows)
            opponent_fielding_avgs = compute_rolling_averages(opponent_data, opponent_name, row['date'], 'fielding_points', windows)
            
            # Append the opponent's metrics to the opponent_features list
            opponent_features += opponent_batting_avgs + opponent_bowling_avgs + opponent_fielding_avgs
        
        # Combine the player's features and opponent features
        full_features = batting_avgs + bowling_avgs + fielding_avgs + opponent_features
        
        # Append the features and target (batting, bowling, fielding points) to the dataset
        features.append(full_features)
        targets.append([row['batting_points'], row['bowling_points'], row['fielding_points']])

# Convert features and targets to numpy arrays
features = np.array(features)
targets = np.array(targets)

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=42)

# Define the Neural Network model
model = Sequential([
    Dense(128, input_dim=X_train.shape[1], activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(3, activation='linear')  # Output: Batting, Bowling, Fielding Points
])

# Compile the model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mae', metrics=['mae'])

# Set up callbacks
log_dir = 'logs/fit/'
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# Change the checkpoint file to save in the .keras format
checkpoint_callback = ModelCheckpoint('model_checkpoint.keras', save_best_only=True, monitor='val_loss', mode='min', verbose=1)

early_stopping_callback = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model with callbacks
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[tensorboard_callback, checkpoint_callback, early_stopping_callback]
)

# Save the final model in .keras format
model.save('final_model.keras')

# Evaluate the model
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f"Test Loss (MAE): {test_loss}")

# Predictions
predictions = model.predict(X_test)

# Display some predictions vs actual
for i in range(5):
    print(f"Actual: {y_test[i]}, Predicted: {predictions[i]}")
# Out:
# Epoch 1/100
# c:\Users\itsme\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 454/491 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.2280 - mae: 11.2280
# Epoch 1: val_loss improved from inf to 10.23877, saving model to model_checkpoint.keras
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.1877 - mae: 11.1877 - val_loss: 10.2388 - val_mae: 10.2388
# Epoch 2/100
# 478/491 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.2790 - mae: 10.2790
# Epoch 2: val_loss improved from 10.23877 to 10.05162, saving model to model_checkpoint.keras
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10.2792 - mae: 10.2792 - val_loss: 10.0516 - val_mae: 10.0516
# Epoch 3/100
# 455/491 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.2387 - mae: 10.2387
# Epoch 3: val_loss did not improve from 10.05162
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.2341 - mae: 10.2341 - val_loss: 10.1552 - val_mae: 10.1552
# Epoch 4/100
# 461/491 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.2485 - mae: 10.2485
# Epoch 4: val_loss did not improve from 10.05162
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10.2413 - mae: 10.2413 - val_loss: 10.1163 - val_mae: 10.1163
# Epoch 5/100
# 452/491 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.1064 - mae: 10.1064
# Epoch 5: val_loss improved from 10.05162 to 10.00042, saving model to model_checkpoint.keras
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10.1061 - mae: 10.1061 - val_loss: 10.0004 - val_mae: 10.0004
# Epoch 6/100
# 459/491 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.0731 - mae: 10.0731
# Epoch 6: val_loss did not improve from 10.00042
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 10.0742 - mae: 10.0742 - val_loss: 10.0084 - val_mae: 10.0084
# Epoch 7/100
# 478/491 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.1132 - mae: 10.1132
# Epoch 7: val_loss did not improve from 10.00042
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.1113 - mae: 10.1113 - val_loss: 10.0019 - val_mae: 10.0019
# Epoch 8/100
# 490/491 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.0284 - mae: 10.0284
# Epoch 8: val_loss did not improve from 10.00042
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.0283 - mae: 10.0283 - val_loss: 10.0242 - val_mae: 10.0242
# Epoch 9/100
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.9940 - mae: 9.9940
# Epoch 9: val_loss did not improve from 10.00042
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.9940 - mae: 9.9940 - val_loss: 10.0390 - val_mae: 10.0390
# Epoch 10/100
# 484/491 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.7528 - mae: 9.7528
# Epoch 10: val_loss did not improve from 10.00042
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7559 - mae: 9.7559 - val_loss: 10.0906 - val_mae: 10.0906
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - loss: 10.1038 - mae: 10.1038
# Test Loss (MAE): 10.101593971252441
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# Actual: [1 0 0], Predicted: [3.0641325 3.9438417 0.5221506]
# Actual: [ 1 25  8], Predicted: [3.23833    0.04504309 0.29173955]
# Actual: [ 0 31 12], Predicted: [ 0.8049478  21.436892   -0.02291099]
# Actual: [10 62 16], Predicted: [12.022249   17.459196    0.24448833]
# Actual: [19  0  0], Predicted: [ 6.779319    0.05657993 -0.06292001]

# %%
model.load_weights('model_checkpoint.h5')
# Continue training...
history = model.fit(...)

# %%
combined_data=np.concatenate((features,targets),axis=1)
df = pd.DataFrame(combined_data)
df.to_csv('combined_data.csv', index=False)

# %%
print(features.shape)
print(targets[1].shape)
# Out:
# (24537, 180)
# (3,)

# %%
import shap
from sklearn.datasets import load_iris
explainer=shap.DeepExplainer(model,X_train)

shap_values=explainer.shap_values(X_test)
shap.summary_plot(shap_values[0], X_test, feature_names=iris.feature_names)
# shap.dependence_plot()
# Out:
# c:\Users\itsme\AppData\Local\Programs\Python\Python312\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# c:\Users\itsme\AppData\Local\Programs\Python\Python312\Lib\site-packages\shap\explainers\_deep\deep_tf.py:155: UserWarning: You have provided over 5k background samples! For better performance consider using smaller random sample.
#   warnings.warn("You have provided over 5k background samples! For better performance consider using smaller random sample.")
# c:\Users\itsme\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: keras_tensor_17. Received: the structure of inputs=['*']
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 6
#       3 explainer=shap.DeepExplainer(model,X_train)
#       5 shap_values=explainer.shap_values(X_test)
# ----> 6 shap.summary_plot(shap_values[0], X_test, feature_names=iris.feature_names)
#       7 # shap.dependence_plot()
#
# NameError: name 'iris' is not defined

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping

def compute_rolling_averages(df, player_name, date, column, windows):
    player_data = df[(df['player_name'] == player_name) & (df['date'] < date)].sort_values(by='date')
    averages = []
    for window in windows:
        avg = player_data[column].tail(window).mean()
        averages.append(avg if not np.isnan(avg) else 0)
    overall_avg = player_data[column].mean()
    averages.append(overall_avg if not np.isnan(overall_avg) else 0)
    return averages

def get_player_features(player_name, date, data_folder, windows):
    """
    Fetches the rolling averages and features for a single player.
    """
    player_file = os.path.join(data_folder, f"{player_name}.csv")
    if not os.path.exists(player_file):
        raise FileNotFoundError(f"Data file for player {player_name} not found.")
    
    # Load player data
    player_data = pd.read_csv(player_file)
    
    # Compute rolling averages for batting, bowling, and fielding points
    batting_avgs = compute_rolling_averages(player_data, player_name, date, 'batting_points', windows)
    bowling_avgs = compute_rolling_averages(player_data, player_name, date, 'bowling_points', windows)
    fielding_avgs = compute_rolling_averages(player_data, player_name, date, 'fielding_points', windows)
    
    return batting_avgs + bowling_avgs + fielding_avgs


def get_team_features(team_players, opponent_players, date, data_folder, windows):
    """
    Computes features for all players in a team against the given opponent players.
    """
    team_features = []
    
    # Compute opponent metrics once for reuse
    opponent_features = []
    for opponent_name in opponent_players:
        opponent_file = os.path.join(data_folder, f"{opponent_name}.csv")
        if not os.path.exists(opponent_file):
            raise FileNotFoundError(f"Data file for opponent player {opponent_name} not found.")
        
        # Load opponent data
        opponent_data = pd.read_csv(opponent_file)
        
        # Compute rolling averages for opponent's batting, bowling, and fielding points
        opponent_batting_avgs = compute_rolling_averages(opponent_data, opponent_name, date, 'batting_points', windows)
        opponent_bowling_avgs = compute_rolling_averages(opponent_data, opponent_name, date, 'bowling_points', windows)
        opponent_fielding_avgs = compute_rolling_averages(opponent_data, opponent_name, date, 'fielding_points', windows)
        
        opponent_features += opponent_batting_avgs + opponent_bowling_avgs + opponent_fielding_avgs
    
    # Compute features for each player in the team
    for player_name in team_players:
        player_features = get_player_features(player_name, date, data_folder, windows)
        full_features = player_features + opponent_features
        team_features.append((player_name, full_features))
    
    return team_features


def select_top_11_players(team1, team2, date, model, data_folder, windows):
    """
    Selects the top 11 players based on predicted fantasy points from two teams,
    including batting, bowling, and fielding points.
    """
    # Compute features for all 22 players
    team1_features = get_team_features(team1, team2, date, data_folder, windows)
    team2_features = get_team_features(team2, team1, date, data_folder, windows)
    
    # Combine all players into a single list
    all_players = team1_features + team2_features
    
    # Extract features for prediction
    player_names = [player[0] for player in all_players]
    feature_matrix = np.array([player[1] for player in all_players])
    
    # Predict fantasy points using the trained model
    predictions = model.predict(feature_matrix)
    total_fantasy_points = predictions.sum(axis=1)  # Sum batting, bowling, and fielding points
    
    # Combine player names with their predicted points
    player_scores = [
        (player_names[i], predictions[i][0], predictions[i][1], predictions[i][2], total_fantasy_points[i])
        for i in range(len(player_names))
    ]
    
    # Sort players by total fantasy points in descending order
    sorted_players = sorted(player_scores, key=lambda x: x[4], reverse=True)
    
    # Select the top 11 players
    top_11_players = sorted_players[:11]
    
    return top_11_players



# Example Usage
team1 = ["RD Gaikwad",
        "DP Conway",
        "RV Uthappa",
        "AT Rayudu",
        "RA Jadeja",
        "S Dube",
        "MS Dhoni",
        "DJ Bravo",
        "MJ Santner",
        "AF Milne",
        "TU Deshpande"]
team2 = ["AM Rahane",
        "VR Iyer",
        "N Rana",
        "SS Iyer",
        "SW Billings",
        "SP Jackson",
        "AD Russell",
        "SP Narine",
        "UT Yadav",
        "Shivam Mavi",
        "CV Varun"]
date = '2022-03-26'  # Replace with the match date



def fetch_actual_points(players, date, data_folder):
    """
    Fetches the actual batting, bowling, fielding, and total points for the given players.
    
    Args:
        players (list): List of player names.
        date (str): The match date for fetching actual points.
        data_folder (str): Path to the folder containing player CSV files.
    
    Returns:
        List of tuples: [(player_name, batting_points, bowling_points, fielding_points, total_points), ...]
    """
    actual_points = []
    
    for player_name in players:
        player_file = os.path.join(data_folder, f"{player_name}.csv")
        if not os.path.exists(player_file):
            raise FileNotFoundError(f"Data file for player {player_name} not found.")
        
        # Load player data
        player_data = pd.read_csv(player_file)
        
        # Find the row matching the given date
        player_row = player_data[player_data['date'] == date]
        if player_row.empty:
            print(f"No data found for player {player_name} on date {date}. Assigning 0 points.")
            batting_points = bowling_points = fielding_points = total_points = 0
        else:
            batting_points = player_row.iloc[0]['batting_points']
            bowling_points = player_row.iloc[0]['bowling_points']
            fielding_points = player_row.iloc[0]['fielding_points']
            total_points = batting_points + bowling_points + fielding_points
        
        # Append to the list
        actual_points.append((player_name, batting_points, bowling_points, fielding_points, total_points))
    
    return actual_points

# %%
# Load the trained model
from tensorflow.keras.models import load_model
model = load_model('final_model.keras')

# Select top 11 players
# Select top 11 players
top_11 = select_top_11_players(team1, team2, date, model, data_folder='player_csv', windows=[3, 5, 10, 20])

# Display the results
print("Top 11 Players Based on Predicted Fantasy Points:")
print(f"{'Player':<15} {'Batting':<10} {'Bowling':<10} {'Fielding':<10} {'Total Points':<15}")
print("-" * 60)
for player, batting, bowling, fielding, total in top_11:
    print(f"{player:<15} {batting:<10.2f} {bowling:<10.2f} {fielding:<10.2f} {total:<15.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Top 11 Players Based on Predicted Fantasy Points:
# Player          Batting    Bowling    Fielding   Total Points
# ------------------------------------------------------------
# RD Gaikwad      28.87      0.01       0.29       29.16
# VR Iyer         27.40      0.02       0.39       27.81
# SP Narine       1.37       25.29      -0.04      26.63
# CV Varun        0.19       26.24      -0.06      26.38
# Shivam Mavi     0.47       25.18      -0.06      25.58
# DJ Bravo        0.99       24.52      -0.04      25.47
# AF Milne        0.92       23.22      0.03       24.18
# MJ Santner      1.70       20.47      0.10       22.27
# UT Yadav        0.09       21.16      -0.09      21.16
# SS Iyer         19.79      -0.03      0.32       20.08
# RV Uthappa      18.44      0.03       0.21       18.68

# %%
actual_points = fetch_actual_points(team1 + team2, date, data_folder='player_csv')

# Display the actual points
print("Actual Points for All 22 Players:")
print(f"{'Player':<15} {'Batting':<10} {'Bowling':<10} {'Fielding':<10} {'Total Points':<15}")
print("-" * 60)
for player, batting, bowling, fielding, total in actual_points:
    print(f"{player:<15} {batting:<10.2f} {bowling:<10.2f} {fielding:<10.2f} {total:<15.2f}")
# Out:
# Actual Points for All 22 Players:
# Player          Batting    Bowling    Fielding   Total Points
# ------------------------------------------------------------
# RD Gaikwad      -2.00      0.00       0.00       -2.00
# DP Conway       3.00       0.00       0.00       3.00
# RV Uthappa      34.00      0.00       0.00       34.00
# AT Rayudu       18.00      0.00       8.00       26.00
# RA Jadeja       28.00      2.00       8.00       38.00
# S Dube          3.00       0.00       0.00       3.00
# MS Dhoni        69.00      0.00       8.00       77.00
# DJ Bravo        0.00       83.00      0.00       83.00
# MJ Santner      0.00       25.00      0.00       25.00
# AF Milne        0.00       0.00       0.00       0.00
# TU Deshpande    0.00       0.00       8.00       8.00
# AM Rahane       56.00      0.00       0.00       56.00
# VR Iyer         18.00      0.00       0.00       18.00
# N Rana          25.00      0.00       8.00       33.00
# SS Iyer         21.00      0.00       14.00      35.00
# SW Billings     28.00      0.00       0.00       28.00
# SP Jackson      3.00       0.00       0.00       3.00
# AD Russell      0.00       25.00      0.00       25.00
# SP Narine       0.00       31.00      14.00      45.00
# UT Yadav        0.00       56.00      0.00       56.00
# Shivam Mavi     0.00       0.00       0.00       0.00
# CV Varun        0.00       29.00      12.00      41.00
